# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

from concurrent.futures import ThreadPoolExecutor
import pickle
    
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, BatchNormalization, Activation, Add,
    MaxPooling2D, GlobalAveragePooling2D, Dense,
    Dropout, Input
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, accuracy_score,
    confusion_matrix, mean_squared_error
)

from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import resample
# Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
dir_images = r'C:\Users\patel\OneDrive\Desktop\FPR\images'
file_meta  = r'C:\Users\patel\OneDrive\Desktop\FPR\myntradataset\styles.csv'

# %%
df_full = pd.read_csv(file_meta,on_bad_lines='skip')
df_full['id'] = df_full['id'].astype(str)

# List images and intersect
files = [f for f in os.listdir(dir_images)
         if f.lower().endswith(('.jpg','.png','.jpeg'))]
ids_all = [os.path.splitext(f)[0] for f in files]
common = list(set(ids_all) & set(df_full['id']))
print(f"Found {len(common)} images with metadata.")

# Sample 1,000 IDs
sample_ids = np.random.choice(common, size=25000, replace=False)
df = df_full[df_full['id'].isin(sample_ids)].reset_index(drop=True)
ids = df['id'].tolist()
print(f"Sampling {len(ids)} images for modeling.")

# Attributes
attrs = ['gender','masterCategory','subCategory',
         'articleType','baseColour','usage']
# Out:
# Found 44419 images with metadata.
# Sampling 25000 images for modeling.

# %%
enc_dir = 'label_encoders'
os.makedirs(enc_dir, exist_ok=True)
label_encoders = {}
num_classes = {}
y_int = {}
for attr in attrs:
    codes, uniques = pd.factorize(df[attr])
    codes
    label_encoders[attr] = uniques
    num_classes[attr] = len(uniques)
    y_int[attr] = codes

# One-hot
Y_oh = {attr: to_categorical(y_int[attr], num_classes[attr])
        for attr in attrs}

# %%
import pandas as pd

# Assuming you’ve already run your factorization:
# label_encoders[attr] = uniques
# y_int[attr] = codes

for attr in attrs:
    uniques = label_encoders[attr]
    codes = list(range(len(uniques)))
    df_map = pd.DataFrame({
        'Encoded': codes,
        'Original': uniques
    })
    print(f"\n=== {attr} Encoding Map ===")
    print(df_map.to_markdown(index=False))
# Out:
# === gender Encoding Map ===
# |   Encoded | Original   |
# |----------:|:-----------|
# |         0 | Men        |
# |         1 | Women      |
# |         2 | Boys       |
# |         3 | Girls      |
# |         4 | Unisex     |
#
# === masterCategory Encoding Map ===
# |   Encoded | Original       |
# |----------:|:---------------|
# |         0 | Apparel        |
# |         1 | Accessories    |
# |         2 | Footwear       |
# |         3 | Personal Care  |
# |         4 | Free Items     |
# |         5 | Sporting Goods |
# |         6 | Home           |
#
# === subCategory Encoding Map ===
# |   Encoded | Original                 |
# |----------:|:-------------------------|
# |         0 | Bottomwear               |
# |         1 | Topwear                  |
# |         2 | Socks                    |
# |         3 | Watches                  |
# |         4 | Shoes                    |
# |         5 | Belts                    |
# |         6 | Flip Flops               |
# |         7 | Bags                     |
# |         8 | Innerwear                |
# |         9 | Shoe Accessories         |
# |        10 | Jewellery                |
# |        11 | Lips                     |
# |        12 | Saree                    |
# |        13 | Fragrance                |
# |        14 | Sandal                   |
# |        15 | Nails                    |
# |        16 | Dress                    |
# |        17 | Wallets                  |
# |        18 | Eyewear                  |
# |        19 | Headwear                 |
# |        20 | Loungewear and Nightwear |
# |        21 | Skin Care                |
# |        22 | Free Gifts               |
# |        23 | Mufflers                 |
# |        24 | Ties                     |
# |        25 | Makeup                   |
# |        26 | Accessories              |
# |        27 | Scarves                  |
# |        28 | Beauty Accessories       |
# |        29 | Water Bottle             |
# |        30 | Apparel Set              |
# |        31 | Skin                     |
# |        32 | Eyes                     |
# |        33 | Sports Accessories       |
# |        34 | Cufflinks                |
# |        35 | Sports Equipment         |
# |        36 | Stoles                   |
# |        37 | Gloves                   |
# |        38 | Hair                     |
# |        39 | Perfumes                 |
# |        40 | Home Furnishing          |
# |        41 | Bath and Body            |
# |        42 | Umbrellas                |
# |        43 | Wristbands               |
# |        44 | Vouchers                 |
#
# === articleType Encoding Map ===
# |   Encoded | Original                  |
# |----------:|:--------------------------|
# |         0 | Track Pants               |
# |         1 | Tshirts                   |
# |         2 | Shirts                    |
# |         3 | Socks                     |
# |         4 | Watches                   |
# |         5 | Casual Shoes              |
# |         6 | Belts                     |
# |         7 | Flip Flops                |
# |         8 | Handbags                  |
# |         9 | Tops                      |
# |        10 | Bra                       |
# |        11 | Shoe Accessories          |
# |        12 | Sweatshirts               |
# |        13 | Formal Shoes              |
# |        14 | Bracelet                  |
# |        15 | Lipstick                  |
# |        16 | Flats                     |
# |        17 | Kurtas                    |
# |        18 | Waistcoat                 |
# |        19 | Sports Shoes              |
# |        20 | Shorts                    |
# |        21 | Briefs                    |
# |        22 | Sarees                    |
# |        23 | Perfume and Body Mist     |
# |        24 | Heels                     |
# |        25 | Sandals                   |
# |        26 | Pendant                   |
# |        27 | Nail Polish               |
# |        28 | Laptop Bag                |
# |        29 | Rain Jacket               |
# |        30 | Dresses                   |
# |        31 | Skirts                    |
# |        32 | Wallets                   |
# |        33 | Blazers                   |
# |        34 | Ring                      |
# |        35 | Sunglasses                |
# |        36 | Clutches                  |
# |        37 | Shrug                     |
# |        38 | Caps                      |
# |        39 | Innerwear Vests           |
# |        40 | Earrings                  |
# |        41 | Trousers                  |
# |        42 | Boxers                    |
# |        43 | Backpacks                 |
# |        44 | Jeans                     |
# |        45 | Jewellery Set             |
# |        46 | Dupatta                   |
# |        47 | Capris                    |
# |        48 | Bath Robe                 |
# |        49 | Tunics                    |
# |        50 | Jackets                   |
# |        51 | Lounge Pants              |
# |        52 | Face Wash and Cleanser    |
# |        53 | Necklace and Chains       |
# |        54 | Duffel Bag                |
# |        55 | Sports Sandals            |
# |        56 | Deodorant                 |
# |        57 | Sweaters                  |
# |        58 | Free Gifts                |
# |        59 | Tracksuits                |
# |        60 | Shoe Laces                |
# |        61 | Trunk                     |
# |        62 | Mufflers                  |
# |        63 | Bangle                    |
# |        64 | Ties                      |
# |        65 | Highlighter and Blush     |
# |        66 | Travel Accessory          |
# |        67 | Lip Care                  |
# |        68 | Scarves                   |
# |        69 | Messenger Bag             |
# |        70 | Compact                   |
# |        71 | Night suits               |
# |        72 | Leggings                  |
# |        73 | Eye Cream                 |
# |        74 | Lip Gloss                 |
# |        75 | Kurtis                    |
# |        76 | Accessory Gift Set        |
# |        77 | Beauty Accessory          |
# |        78 | Jumpsuit                  |
# |        79 | Nightdress                |
# |        80 | Water Bottle              |
# |        81 | Kurta Sets                |
# |        82 | Face Moisturisers         |
# |        83 | Suspenders                |
# |        84 | Mobile Pouch              |
# |        85 | Lip Liner                 |
# |        86 | Robe                      |
# |        87 | Stockings                 |
# |        88 | Kajal and Eyeliner        |
# |        89 | Eyeshadow                 |
# |        90 | Headband                  |
# |        91 | Patiala                   |
# |        92 | Camisoles                 |
# |        93 | Tights                    |
# |        94 | Lounge Tshirts            |
# |        95 | Fragrance Gift Set        |
# |        96 | Face Scrub and Exfoliator |
# |        97 | Lounge Shorts             |
# |        98 | Baby Dolls                |
# |        99 | Foundation and Primer     |
# |       100 | Wristbands                |
# |       101 | Salwar and Dupatta        |
# |       102 | Swimwear                  |
# |       103 | Tablet Sleeve             |
# |       104 | Ties and Cufflinks        |
# |       105 | Footballs                 |
# |       106 | Stoles                    |
# |       107 | Shapewear                 |
# |       108 | Salwar                    |
# |       109 | Cufflinks                 |
# |       110 | Concealer                 |
# |       111 | Rompers                   |
# |       112 | Jeggings                  |
# |       113 | Gloves                    |
# |       114 | Sunscreen                 |
# |       115 | Booties                   |
# |       116 | Mask and Peel             |
# |       117 | Waist Pouch               |
# |       118 | Rucksacks                 |
# |       119 | Basketballs               |
# |       120 | Hair Colour               |
# |       121 | Churidar                  |
# |       122 | Clothing Set              |
# |       123 | Mascara                   |
# |       124 | Nehru Jackets             |
# |       125 | Cushion Covers            |
# |       126 | Key chain                 |
# |       127 | Toner                     |
# |       128 | Lip Plumper               |
# |       129 | Nail Essentials           |
# |       130 | Umbrellas                 |
# |       131 | Face Serum and Gel        |
# |       132 | Body Lotion               |
# |       133 | Makeup Remover            |
# |       134 | Rain Trousers             |
# |       135 | Hat                       |
# |       136 | Trolley Bag               |
# |       137 | Lehenga Choli             |
# |       138 | Ipad                      |
#
# === baseColour Encoding Map ===
# |   Encoded | Original          |
# |----------:|:------------------|
# |         0 | Black             |
# |         1 | Grey              |
# |         2 | Green             |
# |         3 | Navy Blue         |
# |         4 | Blue              |
# |         5 | White             |
# |         6 | Beige             |
# |         7 | Bronze            |
# |         8 | Brown             |
# |         9 | Copper            |
# |        10 | Pink              |
# |        11 | Off White         |
# |        12 | Maroon            |
# |        13 | Purple            |
# |        14 | Khaki             |
# |        15 | Silver            |
# |        16 | Orange            |
# |        17 | Coffee Brown      |
# |        18 | Red               |
# |        19 | Charcoal          |
# |        20 | Gold              |
# |        21 | Steel             |
# |        22 | Multi             |
# |        23 | Magenta           |
# |        24 | Sea Green         |
# |        25 | Cream             |
# |        26 | Yellow            |
# |        27 | Olive             |
# |        28 | Grey Melange      |
# |        29 | Teal              |
# |        30 | Burgundy          |
# |        31 | Peach             |
# |        32 | Rust              |
# |        33 | Skin              |
# |        34 | Turquoise Blue    |
# |        35 | Tan               |
# |        36 | Lavender          |
# |        37 | Metallic          |
# |        38 | Mustard           |
# |        39 | Mauve             |
# |        40 | Nude              |
# |        41 | Rose              |
# |        42 | Mushroom Brown    |
# |        43 | Taupe             |
# |        44 | Lime Green        |
# |        45 | Fluorescent Green |
#
# === usage Encoding Map ===
# |   Encoded | Original     |
# |----------:|:-------------|
# |         0 | Casual       |
# |         1 | Ethnic       |
# |         2 | Sports       |
# |         3 | Formal       |
# |         4 | Smart Casual |
# |         5 | Party        |
# |         6 | Travel       |
# |         7 | Home         |

# %%
IMG_SIZE = (128, 128)
NUM_THREADS = 8  # You can tune this based on your CPU

def load_img(id_):
    try:
        img_path = os.path.join(dir_images, f"{id_}.jpg")
        img = Image.open(img_path).convert('RGB').resize(IMG_SIZE)
        return np.array(img) / 255.0
    except Exception as e:
        print(f"Error loading image {id_}: {e}")
        return np.zeros((*IMG_SIZE, 3))  # Fallback to blank image if error

# --- Parallel image loading ---
with ThreadPoolExecutor(max_workers=NUM_THREADS) as executor:
    X = np.array(list(executor.map(load_img, ids)))

# --- Labels ---
Y = [Y_oh[attr] for attr in attrs]

# --- Output Shapes ---
print("X shape:", X.shape)
for attr in attrs:
    print(f"{attr} one-hot shape:", Y_oh[attr].shape)
# Out:
# X shape: (25000, 128, 128, 3)
# gender one-hot shape: (25000, 5)
# masterCategory one-hot shape: (25000, 7)
# subCategory one-hot shape: (25000, 45)
# articleType one-hot shape: (25000, 139)
# baseColour one-hot shape: (25000, 46)
# usage one-hot shape: (25000, 8)

# %%
idx = np.arange(len(X))
i_tr, i_te = train_test_split(idx, test_size=0.2, random_state=42)
X_tr, X_te = X[i_tr], X[i_te]
y_tr = [Y[k][i_tr] for k in range(len(attrs))]
y_te = [Y[k][i_te] for k in range(len(attrs))]
y_te_int = [y_int[attr][i_te] for attr in attrs]
print("Train/Test shapes:", X_tr.shape, X_te.shape)
# Out:
# Train/Test shapes: (20000, 128, 128, 3) (5000, 128, 128, 3)

# %%
def build_model_complex(input_shape, attrs, num_classes, wd=1e-4):
    def conv_block(x, filters):
        x = Conv2D(filters, 3, padding='same', kernel_regularizer=l2(wd))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x

    def res_block(x, filters):
        shortcut = x
        x = conv_block(x, filters)
        x = conv_block(x, filters)
        if shortcut.shape[-1] != filters:
            shortcut = Conv2D(filters,1,padding='same',kernel_regularizer=l2(wd))(shortcut)
            shortcut = BatchNormalization()(shortcut)
        x = Add()([x, shortcut])
        return Activation('relu')(x)

    inp = Input(shape=input_shape)
    x = conv_block(inp, 32)
    x = MaxPooling2D()(x)
    x = res_block(x, 64)
    x = MaxPooling2D()(x)
    x = res_block(x, 128)
    x = MaxPooling2D()(x)
    x = res_block(x, 256)
    x = MaxPooling2D()(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(wd))(x)
    x = Dropout(0.5)(x)
    outs = [Dense(num_classes[a], activation='softmax',
                 name=a, kernel_regularizer=l2(wd))(x)
            for a in attrs]
    m = Model(inp, outs)
    m.compile(
        optimizer=Adam(1e-3),
        loss={a:'categorical_crossentropy' for a in attrs},
        metrics={a:['accuracy'] for a in attrs}
    )
    return m

# %%
import numpy as np

batch_sizes = [16, 32, 64]
epochs = 10
histories = {}
models = {}

best_acc = 0.0
best_bs = None

for bs in batch_sizes:
    print(f"Training bs={bs}")
    model = build_model_complex((*IMG_SIZE, 3), attrs, num_classes)
    hist = model.fit(
        X_tr,
        {a: y_tr[i] for i, a in enumerate(attrs)},
        validation_data=(X_te, {a: y_te[i] for i, a in enumerate(attrs)}),
        epochs=epochs,
        batch_size=bs,
        verbose=1,
    )
    histories[bs] = hist
    models[bs] = model

    
    final_epoch = epochs - 1
    val_accs = [hist.history[f'val_{a}_accuracy'][final_epoch] for a in attrs]
    mean_val_acc = np.mean(val_accs)
    print(f"Mean val accuracy for bs={bs}: {mean_val_acc:.4f}")

    if mean_val_acc > best_acc:
        best_acc = mean_val_acc
        best_bs = bs
# Out:
# Training bs=16
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 489s 385ms/step - articleType_accuracy: 0.2806 - articleType_loss: 2.9636 - baseColour_accuracy: 0.3544 - baseColour_loss: 2.4398 - gender_accuracy: 0.6104 - gender_loss: 0.9385 - loss: 9.6044 - masterCategory_accuracy: 0.7669 - masterCategory_loss: 0.6192 - subCategory_accuracy: 0.5709 - subCategory_loss: 1.6569 - usage_accuracy: 0.7631 - usage_loss: 0.7979 - val_articleType_accuracy: 0.2568 - val_articleType_loss: 2.9651 - val_baseColour_accuracy: 0.3404 - val_baseColour_loss: 2.4236 - val_gender_accuracy: 0.5880 - val_gender_loss: 0.9401 - val_loss: 10.1907 - val_masterCategory_accuracy: 0.7970 - val_masterCategory_loss: 0.5926 - val_subCategory_accuracy: 0.3866 - val_subCategory_loss: 2.1908 - val_usage_accuracy: 0.7742 - val_usage_loss: 0.8295
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 442s 354ms/step - articleType_accuracy: 0.5232 - articleType_loss: 1.6925 - baseColour_accuracy: 0.4503 - baseColour_loss: 1.9535 - gender_accuracy: 0.7454 - gender_loss: 0.6550 - loss: 6.1684 - masterCategory_accuracy: 0.9269 - masterCategory_loss: 0.2293 - subCategory_accuracy: 0.7840 - subCategory_loss: 0.7899 - usage_accuracy: 0.7979 - usage_loss: 0.5831 - val_articleType_accuracy: 0.4912 - val_articleType_loss: 1.9000 - val_baseColour_accuracy: 0.3498 - val_baseColour_loss: 2.2927 - val_gender_accuracy: 0.7802 - val_gender_loss: 0.6895 - val_loss: 7.3404 - val_masterCategory_accuracy: 0.8888 - val_masterCategory_loss: 0.4065 - val_subCategory_accuracy: 0.7194 - val_subCategory_loss: 1.1804 - val_usage_accuracy: 0.8046 - val_usage_loss: 0.5591
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 443s 354ms/step - articleType_accuracy: 0.6064 - articleType_loss: 1.3682 - baseColour_accuracy: 0.4823 - baseColour_loss: 1.8100 - gender_accuracy: 0.7841 - gender_loss: 0.5726 - loss: 5.3596 - masterCategory_accuracy: 0.9529 - masterCategory_loss: 0.1646 - subCategory_accuracy: 0.8320 - subCategory_loss: 0.6010 - usage_accuracy: 0.8213 - usage_loss: 0.5168 - val_articleType_accuracy: 0.4490 - val_articleType_loss: 2.2359 - val_baseColour_accuracy: 0.3684 - val_baseColour_loss: 2.5905 - val_gender_accuracy: 0.7856 - val_gender_loss: 0.6592 - val_loss: 8.6045 - val_masterCategory_accuracy: 0.7568 - val_masterCategory_loss: 0.7333 - val_subCategory_accuracy: 0.6832 - val_subCategory_loss: 1.3102 - val_usage_accuracy: 0.7886 - val_usage_loss: 0.7095
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 426s 341ms/step - articleType_accuracy: 0.6445 - articleType_loss: 1.2024 - baseColour_accuracy: 0.5091 - baseColour_loss: 1.7069 - gender_accuracy: 0.8081 - gender_loss: 0.5237 - loss: 4.9309 - masterCategory_accuracy: 0.9611 - masterCategory_loss: 0.1400 - subCategory_accuracy: 0.8619 - subCategory_loss: 0.4981 - usage_accuracy: 0.8290 - usage_loss: 0.4821 - val_articleType_accuracy: 0.3636 - val_articleType_loss: 2.7602 - val_baseColour_accuracy: 0.3484 - val_baseColour_loss: 2.6414 - val_gender_accuracy: 0.6540 - val_gender_loss: 0.7498 - val_loss: 9.2940 - val_masterCategory_accuracy: 0.8818 - val_masterCategory_loss: 0.5773 - val_subCategory_accuracy: 0.6664 - val_subCategory_loss: 1.5711 - val_usage_accuracy: 0.7994 - val_usage_loss: 0.5831
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 432s 346ms/step - articleType_accuracy: 0.6751 - articleType_loss: 1.0919 - baseColour_accuracy: 0.5272 - baseColour_loss: 1.6381 - gender_accuracy: 0.8249 - gender_loss: 0.4819 - loss: 4.6439 - masterCategory_accuracy: 0.9657 - masterCategory_loss: 0.1196 - subCategory_accuracy: 0.8766 - subCategory_loss: 0.4378 - usage_accuracy: 0.8380 - usage_loss: 0.4550 - val_articleType_accuracy: 0.4996 - val_articleType_loss: 2.0800 - val_baseColour_accuracy: 0.3902 - val_baseColour_loss: 2.3236 - val_gender_accuracy: 0.7834 - val_gender_loss: 0.5774 - val_loss: 7.6697 - val_masterCategory_accuracy: 0.8218 - val_masterCategory_loss: 0.4940 - val_subCategory_accuracy: 0.6772 - val_subCategory_loss: 1.2409 - val_usage_accuracy: 0.8212 - val_usage_loss: 0.5070
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 438s 350ms/step - articleType_accuracy: 0.6929 - articleType_loss: 1.0041 - baseColour_accuracy: 0.5405 - baseColour_loss: 1.5904 - gender_accuracy: 0.8292 - gender_loss: 0.4563 - loss: 4.4450 - masterCategory_accuracy: 0.9705 - masterCategory_loss: 0.1047 - subCategory_accuracy: 0.8872 - subCategory_loss: 0.3979 - usage_accuracy: 0.8467 - usage_loss: 0.4348 - val_articleType_accuracy: 0.6816 - val_articleType_loss: 1.0991 - val_baseColour_accuracy: 0.5492 - val_baseColour_loss: 1.5894 - val_gender_accuracy: 0.8412 - val_gender_loss: 0.4249 - val_loss: 4.7885 - val_masterCategory_accuracy: 0.9244 - val_masterCategory_loss: 0.2181 - val_subCategory_accuracy: 0.8518 - val_subCategory_loss: 0.5186 - val_usage_accuracy: 0.8364 - val_usage_loss: 0.4577
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 443s 355ms/step - articleType_accuracy: 0.7118 - articleType_loss: 0.9442 - baseColour_accuracy: 0.5502 - baseColour_loss: 1.5487 - gender_accuracy: 0.8391 - gender_loss: 0.4396 - loss: 4.3044 - masterCategory_accuracy: 0.9739 - masterCategory_loss: 0.0967 - subCategory_accuracy: 0.8955 - subCategory_loss: 0.3626 - usage_accuracy: 0.8560 - usage_loss: 0.4225 - val_articleType_accuracy: 0.6578 - val_articleType_loss: 1.2685 - val_baseColour_accuracy: 0.5328 - val_baseColour_loss: 1.6556 - val_gender_accuracy: 0.8222 - val_gender_loss: 0.4643 - val_loss: 5.1653 - val_masterCategory_accuracy: 0.9372 - val_masterCategory_loss: 0.1978 - val_subCategory_accuracy: 0.8242 - val_subCategory_loss: 0.6147 - val_usage_accuracy: 0.8416 - val_usage_loss: 0.4560
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 438s 350ms/step - articleType_accuracy: 0.7317 - articleType_loss: 0.8782 - baseColour_accuracy: 0.5639 - baseColour_loss: 1.5086 - gender_accuracy: 0.8495 - gender_loss: 0.4179 - loss: 4.1472 - masterCategory_accuracy: 0.9763 - masterCategory_loss: 0.0903 - subCategory_accuracy: 0.9038 - subCategory_loss: 0.3330 - usage_accuracy: 0.8572 - usage_loss: 0.4009 - val_articleType_accuracy: 0.5794 - val_articleType_loss: 1.6115 - val_baseColour_accuracy: 0.5242 - val_baseColour_loss: 1.8154 - val_gender_accuracy: 0.7316 - val_gender_loss: 0.6483 - val_loss: 6.2178 - val_masterCategory_accuracy: 0.9274 - val_masterCategory_loss: 0.2310 - val_subCategory_accuracy: 0.7712 - val_subCategory_loss: 0.8415 - val_usage_accuracy: 0.8194 - val_usage_loss: 0.5322
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 448s 358ms/step - articleType_accuracy: 0.7402 - articleType_loss: 0.8348 - baseColour_accuracy: 0.5716 - baseColour_loss: 1.4592 - gender_accuracy: 0.8572 - gender_loss: 0.3999 - loss: 4.0067 - masterCategory_accuracy: 0.9783 - masterCategory_loss: 0.0808 - subCategory_accuracy: 0.9114 - subCategory_loss: 0.2994 - usage_accuracy: 0.8616 - usage_loss: 0.3861 - val_articleType_accuracy: 0.7312 - val_articleType_loss: 0.8996 - val_baseColour_accuracy: 0.5586 - val_baseColour_loss: 1.5877 - val_gender_accuracy: 0.8436 - val_gender_loss: 0.4191 - val_loss: 4.3197 - val_masterCategory_accuracy: 0.9744 - val_masterCategory_loss: 0.0887 - val_subCategory_accuracy: 0.8940 - val_subCategory_loss: 0.3597 - val_usage_accuracy: 0.8680 - val_usage_loss: 0.3987
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 461s 368ms/step - articleType_accuracy: 0.7496 - articleType_loss: 0.7967 - baseColour_accuracy: 0.5825 - baseColour_loss: 1.4287 - gender_accuracy: 0.8565 - gender_loss: 0.3939 - loss: 3.9393 - masterCategory_accuracy: 0.9790 - masterCategory_loss: 0.0780 - subCategory_accuracy: 0.9149 - subCategory_loss: 0.2874 - usage_accuracy: 0.8663 - usage_loss: 0.3797 - val_articleType_accuracy: 0.6200 - val_articleType_loss: 1.2807 - val_baseColour_accuracy: 0.5826 - val_baseColour_loss: 1.4435 - val_gender_accuracy: 0.8374 - val_gender_loss: 0.4209 - val_loss: 4.9278 - val_masterCategory_accuracy: 0.9366 - val_masterCategory_loss: 0.1964 - val_subCategory_accuracy: 0.8422 - val_subCategory_loss: 0.5583 - val_usage_accuracy: 0.8548 - val_usage_loss: 0.4378
# Mean val accuracy for bs=16: 0.7789
# Training bs=32
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 462s 727ms/step - articleType_accuracy: 0.2694 - articleType_loss: 3.0776 - baseColour_accuracy: 0.3693 - baseColour_loss: 2.3989 - gender_accuracy: 0.6099 - gender_loss: 0.9284 - loss: 9.8823 - masterCategory_accuracy: 0.7406 - masterCategory_loss: 0.6735 - subCategory_accuracy: 0.5469 - subCategory_loss: 1.8002 - usage_accuracy: 0.7582 - usage_loss: 0.8190 - val_articleType_accuracy: 0.1396 - val_articleType_loss: 3.8812 - val_baseColour_accuracy: 0.2404 - val_baseColour_loss: 2.5441 - val_gender_accuracy: 0.5096 - val_gender_loss: 1.1615 - val_loss: 14.2899 - val_masterCategory_accuracy: 0.4908 - val_masterCategory_loss: 2.3509 - val_subCategory_accuracy: 0.4068 - val_subCategory_loss: 3.1700 - val_usage_accuracy: 0.5948 - val_usage_loss: 0.9559
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 439s 702ms/step - articleType_accuracy: 0.5412 - articleType_loss: 1.6596 - baseColour_accuracy: 0.4841 - baseColour_loss: 1.8356 - gender_accuracy: 0.7564 - gender_loss: 0.6234 - loss: 5.9164 - masterCategory_accuracy: 0.9277 - masterCategory_loss: 0.2273 - subCategory_accuracy: 0.7873 - subCategory_loss: 0.7771 - usage_accuracy: 0.8023 - usage_loss: 0.5670 - val_articleType_accuracy: 0.4744 - val_articleType_loss: 1.8027 - val_baseColour_accuracy: 0.4700 - val_baseColour_loss: 1.7932 - val_gender_accuracy: 0.7894 - val_gender_loss: 0.5954 - val_loss: 6.2895 - val_masterCategory_accuracy: 0.8476 - val_masterCategory_loss: 0.3832 - val_subCategory_accuracy: 0.7086 - val_subCategory_loss: 0.9349 - val_usage_accuracy: 0.8304 - val_usage_loss: 0.5242
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 440s 705ms/step - articleType_accuracy: 0.6157 - articleType_loss: 1.3210 - baseColour_accuracy: 0.5242 - baseColour_loss: 1.6905 - gender_accuracy: 0.7967 - gender_loss: 0.5418 - loss: 5.0555 - masterCategory_accuracy: 0.9519 - masterCategory_loss: 0.1605 - subCategory_accuracy: 0.8399 - subCategory_loss: 0.5770 - usage_accuracy: 0.8224 - usage_loss: 0.5022 - val_articleType_accuracy: 0.1626 - val_articleType_loss: 9.1271 - val_baseColour_accuracy: 0.4478 - val_baseColour_loss: 2.8322 - val_gender_accuracy: 0.4422 - val_gender_loss: 4.4756 - val_loss: 31.2870 - val_masterCategory_accuracy: 0.3234 - val_masterCategory_loss: 6.3360 - val_subCategory_accuracy: 0.4110 - val_subCategory_loss: 6.2661 - val_usage_accuracy: 0.7290 - val_usage_loss: 1.9072
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 443s 709ms/step - articleType_accuracy: 0.6606 - articleType_loss: 1.1539 - baseColour_accuracy: 0.5458 - baseColour_loss: 1.5929 - gender_accuracy: 0.8198 - gender_loss: 0.4831 - loss: 4.6031 - masterCategory_accuracy: 0.9608 - masterCategory_loss: 0.1328 - subCategory_accuracy: 0.8626 - subCategory_loss: 0.4826 - usage_accuracy: 0.8338 - usage_loss: 0.4636 - val_articleType_accuracy: 0.0708 - val_articleType_loss: 14.5872 - val_baseColour_accuracy: 0.3802 - val_baseColour_loss: 4.1688 - val_gender_accuracy: 0.4332 - val_gender_loss: 6.2827 - val_loss: 49.0934 - val_masterCategory_accuracy: 0.2694 - val_masterCategory_loss: 9.5826 - val_subCategory_accuracy: 0.1642 - val_subCategory_loss: 11.7074 - val_usage_accuracy: 0.8038 - val_usage_loss: 2.4131
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 442s 707ms/step - articleType_accuracy: 0.6868 - articleType_loss: 1.0455 - baseColour_accuracy: 0.5613 - baseColour_loss: 1.5394 - gender_accuracy: 0.8304 - gender_loss: 0.4615 - loss: 4.3498 - masterCategory_accuracy: 0.9686 - masterCategory_loss: 0.1152 - subCategory_accuracy: 0.8808 - subCategory_loss: 0.4214 - usage_accuracy: 0.8427 - usage_loss: 0.4425 - val_articleType_accuracy: 0.2856 - val_articleType_loss: 5.6344 - val_baseColour_accuracy: 0.4288 - val_baseColour_loss: 2.7599 - val_gender_accuracy: 0.4492 - val_gender_loss: 4.6814 - val_loss: 21.3363 - val_masterCategory_accuracy: 0.4360 - val_masterCategory_loss: 3.2616 - val_subCategory_accuracy: 0.5498 - val_subCategory_loss: 3.1910 - val_usage_accuracy: 0.7872 - val_usage_loss: 1.4319
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 447s 715ms/step - articleType_accuracy: 0.7052 - articleType_loss: 0.9600 - baseColour_accuracy: 0.5706 - baseColour_loss: 1.4959 - gender_accuracy: 0.8379 - gender_loss: 0.4400 - loss: 4.1436 - masterCategory_accuracy: 0.9716 - masterCategory_loss: 0.1002 - subCategory_accuracy: 0.8942 - subCategory_loss: 0.3707 - usage_accuracy: 0.8511 - usage_loss: 0.4257 - val_articleType_accuracy: 0.2124 - val_articleType_loss: 6.0544 - val_baseColour_accuracy: 0.4336 - val_baseColour_loss: 2.8222 - val_gender_accuracy: 0.4372 - val_gender_loss: 4.6259 - val_loss: 22.6415 - val_masterCategory_accuracy: 0.5412 - val_masterCategory_loss: 3.1485 - val_subCategory_accuracy: 0.4556 - val_subCategory_loss: 3.9446 - val_usage_accuracy: 0.7938 - val_usage_loss: 1.6604
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 455s 727ms/step - articleType_accuracy: 0.7240 - articleType_loss: 0.8953 - baseColour_accuracy: 0.5746 - baseColour_loss: 1.4634 - gender_accuracy: 0.8474 - gender_loss: 0.4225 - loss: 3.9962 - masterCategory_accuracy: 0.9733 - masterCategory_loss: 0.0931 - subCategory_accuracy: 0.9046 - subCategory_loss: 0.3391 - usage_accuracy: 0.8566 - usage_loss: 0.4069 - val_articleType_accuracy: 0.2816 - val_articleType_loss: 4.9142 - val_baseColour_accuracy: 0.4594 - val_baseColour_loss: 2.2007 - val_gender_accuracy: 0.4678 - val_gender_loss: 3.8585 - val_loss: 17.1931 - val_masterCategory_accuracy: 0.7866 - val_masterCategory_loss: 1.4098 - val_subCategory_accuracy: 0.6018 - val_subCategory_loss: 3.1598 - val_usage_accuracy: 0.7876 - val_usage_loss: 1.2245
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 443s 709ms/step - articleType_accuracy: 0.7339 - articleType_loss: 0.8503 - baseColour_accuracy: 0.5868 - baseColour_loss: 1.4259 - gender_accuracy: 0.8528 - gender_loss: 0.3996 - loss: 3.8737 - masterCategory_accuracy: 0.9761 - masterCategory_loss: 0.0858 - subCategory_accuracy: 0.9098 - subCategory_loss: 0.3149 - usage_accuracy: 0.8571 - usage_loss: 0.3981 - val_articleType_accuracy: 0.1870 - val_articleType_loss: 8.2524 - val_baseColour_accuracy: 0.3216 - val_baseColour_loss: 3.9080 - val_gender_accuracy: 0.5248 - val_gender_loss: 2.8314 - val_loss: 32.0033 - val_masterCategory_accuracy: 0.2992 - val_masterCategory_loss: 8.7790 - val_subCategory_accuracy: 0.4150 - val_subCategory_loss: 5.8460 - val_usage_accuracy: 0.6688 - val_usage_loss: 1.9311
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 444s 710ms/step - articleType_accuracy: 0.7507 - articleType_loss: 0.7995 - baseColour_accuracy: 0.5867 - baseColour_loss: 1.3925 - gender_accuracy: 0.8613 - gender_loss: 0.3868 - loss: 3.7412 - masterCategory_accuracy: 0.9795 - masterCategory_loss: 0.0758 - subCategory_accuracy: 0.9140 - subCategory_loss: 0.2905 - usage_accuracy: 0.8662 - usage_loss: 0.3746 - val_articleType_accuracy: 0.2296 - val_articleType_loss: 8.8908 - val_baseColour_accuracy: 0.3496 - val_baseColour_loss: 3.2909 - val_gender_accuracy: 0.5056 - val_gender_loss: 3.8776 - val_loss: 35.1277 - val_masterCategory_accuracy: 0.4088 - val_masterCategory_loss: 7.9232 - val_subCategory_accuracy: 0.3560 - val_subCategory_loss: 8.6024 - val_usage_accuracy: 0.8004 - val_usage_loss: 2.0454
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 444s 710ms/step - articleType_accuracy: 0.7624 - articleType_loss: 0.7537 - baseColour_accuracy: 0.6011 - baseColour_loss: 1.3610 - gender_accuracy: 0.8622 - gender_loss: 0.3759 - loss: 3.6406 - masterCategory_accuracy: 0.9804 - masterCategory_loss: 0.0739 - subCategory_accuracy: 0.9234 - subCategory_loss: 0.2674 - usage_accuracy: 0.8661 - usage_loss: 0.3669 - val_articleType_accuracy: 0.1630 - val_articleType_loss: 10.8605 - val_baseColour_accuracy: 0.4296 - val_baseColour_loss: 3.0702 - val_gender_accuracy: 0.4546 - val_gender_loss: 5.4006 - val_loss: 38.3511 - val_masterCategory_accuracy: 0.4820 - val_masterCategory_loss: 6.5666 - val_subCategory_accuracy: 0.3564 - val_subCategory_loss: 8.9803 - val_usage_accuracy: 0.4608 - val_usage_loss: 2.9360
# Mean val accuracy for bs=32: 0.3911
# Training bs=64
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 454s 1s/step - articleType_accuracy: 0.2497 - articleType_loss: 3.2485 - baseColour_accuracy: 0.3721 - baseColour_loss: 2.3919 - gender_accuracy: 0.6133 - gender_loss: 0.9477 - loss: 10.2452 - masterCategory_accuracy: 0.7184 - masterCategory_loss: 0.7457 - subCategory_accuracy: 0.5297 - subCategory_loss: 1.8917 - usage_accuracy: 0.7505 - usage_loss: 0.8427 - val_articleType_accuracy: 0.1468 - val_articleType_loss: 4.0199 - val_baseColour_accuracy: 0.1570 - val_baseColour_loss: 3.2027 - val_gender_accuracy: 0.4388 - val_gender_loss: 1.9298 - val_loss: 15.2932 - val_masterCategory_accuracy: 0.3566 - val_masterCategory_loss: 2.3168 - val_subCategory_accuracy: 0.3426 - val_subCategory_loss: 2.6883 - val_usage_accuracy: 0.7724 - val_usage_loss: 0.9335
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - articleType_accuracy: 0.5283 - articleType_loss: 1.7330 - baseColour_accuracy: 0.5013 - baseColour_loss: 1.7982 - gender_accuracy: 0.7600 - gender_loss: 0.6201 - loss: 5.9680 - masterCategory_accuracy: 0.9245 - masterCategory_loss: 0.2376 - subCategory_accuracy: 0.7803 - subCategory_loss: 0.8172 - usage_accuracy: 0.8010 - usage_loss: 0.5648 - val_articleType_accuracy: 0.0700 - val_articleType_loss: 12.6900 - val_baseColour_accuracy: 0.3532 - val_baseColour_loss: 2.9804 - val_gender_accuracy: 0.4358 - val_gender_loss: 6.1376 - val_loss: 38.2823 - val_masterCategory_accuracy: 0.3888 - val_masterCategory_loss: 5.6937 - val_subCategory_accuracy: 0.2970 - val_subCategory_loss: 8.5675 - val_usage_accuracy: 0.7836 - val_usage_loss: 1.8909
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - articleType_accuracy: 0.6151 - articleType_loss: 1.3582 - baseColour_accuracy: 0.5325 - baseColour_loss: 1.6693 - gender_accuracy: 0.7969 - gender_loss: 0.5441 - loss: 5.0543 - masterCategory_accuracy: 0.9528 - masterCategory_loss: 0.1662 - subCategory_accuracy: 0.8322 - subCategory_loss: 0.5997 - usage_accuracy: 0.8235 - usage_loss: 0.4980 - val_articleType_accuracy: 0.0448 - val_articleType_loss: 18.0832 - val_baseColour_accuracy: 0.3130 - val_baseColour_loss: 4.8227 - val_gender_accuracy: 0.4276 - val_gender_loss: 8.9816 - val_loss: 52.3918 - val_masterCategory_accuracy: 0.3204 - val_masterCategory_loss: 5.8695 - val_subCategory_accuracy: 0.1562 - val_subCategory_loss: 11.9861 - val_usage_accuracy: 0.8024 - val_usage_loss: 2.3432
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - articleType_accuracy: 0.6620 - articleType_loss: 1.1571 - baseColour_accuracy: 0.5516 - baseColour_loss: 1.5694 - gender_accuracy: 0.8160 - gender_loss: 0.4989 - loss: 4.5351 - masterCategory_accuracy: 0.9609 - masterCategory_loss: 0.1367 - subCategory_accuracy: 0.8682 - subCategory_loss: 0.4765 - usage_accuracy: 0.8383 - usage_loss: 0.4575 - val_articleType_accuracy: 0.1108 - val_articleType_loss: 9.2959 - val_baseColour_accuracy: 0.3768 - val_baseColour_loss: 3.1656 - val_gender_accuracy: 0.4408 - val_gender_loss: 4.9094 - val_loss: 28.9198 - val_masterCategory_accuracy: 0.4594 - val_masterCategory_loss: 3.7153 - val_subCategory_accuracy: 0.3184 - val_subCategory_loss: 5.9421 - val_usage_accuracy: 0.7768 - val_usage_loss: 1.6244
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - articleType_accuracy: 0.6959 - articleType_loss: 1.0385 - baseColour_accuracy: 0.5678 - baseColour_loss: 1.5025 - gender_accuracy: 0.8321 - gender_loss: 0.4670 - loss: 4.2250 - masterCategory_accuracy: 0.9689 - masterCategory_loss: 0.1140 - subCategory_accuracy: 0.8840 - subCategory_loss: 0.4125 - usage_accuracy: 0.8448 - usage_loss: 0.4332 - val_articleType_accuracy: 0.0802 - val_articleType_loss: 11.3553 - val_baseColour_accuracy: 0.3950 - val_baseColour_loss: 3.1658 - val_gender_accuracy: 0.4336 - val_gender_loss: 7.1466 - val_loss: 33.9941 - val_masterCategory_accuracy: 0.5896 - val_masterCategory_loss: 2.3333 - val_subCategory_accuracy: 0.2462 - val_subCategory_loss: 7.9895 - val_usage_accuracy: 0.7884 - val_usage_loss: 1.6769
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - articleType_accuracy: 0.7087 - articleType_loss: 0.9609 - baseColour_accuracy: 0.5867 - baseColour_loss: 1.4495 - gender_accuracy: 0.8437 - gender_loss: 0.4408 - loss: 4.0169 - masterCategory_accuracy: 0.9735 - masterCategory_loss: 0.1017 - subCategory_accuracy: 0.8958 - subCategory_loss: 0.3720 - usage_accuracy: 0.8496 - usage_loss: 0.4177 - val_articleType_accuracy: 0.3808 - val_articleType_loss: 3.3051 - val_baseColour_accuracy: 0.3614 - val_baseColour_loss: 3.2402 - val_gender_accuracy: 0.6334 - val_gender_loss: 1.2022 - val_loss: 13.1468 - val_masterCategory_accuracy: 0.7234 - val_masterCategory_loss: 1.3191 - val_subCategory_accuracy: 0.5236 - val_subCategory_loss: 2.9142 - val_usage_accuracy: 0.8216 - val_usage_loss: 0.8315
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - articleType_accuracy: 0.7300 - articleType_loss: 0.8868 - baseColour_accuracy: 0.5890 - baseColour_loss: 1.4262 - gender_accuracy: 0.8480 - gender_loss: 0.4224 - loss: 3.8421 - masterCategory_accuracy: 0.9740 - masterCategory_loss: 0.0892 - subCategory_accuracy: 0.9016 - subCategory_loss: 0.3307 - usage_accuracy: 0.8579 - usage_loss: 0.3971 - val_articleType_accuracy: 0.6404 - val_articleType_loss: 1.2739 - val_baseColour_accuracy: 0.4372 - val_baseColour_loss: 2.1258 - val_gender_accuracy: 0.7838 - val_gender_loss: 0.5243 - val_loss: 5.5790 - val_masterCategory_accuracy: 0.9516 - val_masterCategory_loss: 0.1550 - val_subCategory_accuracy: 0.7856 - val_subCategory_loss: 0.7067 - val_usage_accuracy: 0.8430 - val_usage_loss: 0.4882
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 442s 1s/step - articleType_accuracy: 0.7416 - articleType_loss: 0.8323 - baseColour_accuracy: 0.5986 - baseColour_loss: 1.3680 - gender_accuracy: 0.8530 - gender_loss: 0.4035 - loss: 3.6873 - masterCategory_accuracy: 0.9761 - masterCategory_loss: 0.0876 - subCategory_accuracy: 0.9072 - subCategory_loss: 0.3107 - usage_accuracy: 0.8638 - usage_loss: 0.3802 - val_articleType_accuracy: 0.2822 - val_articleType_loss: 5.2607 - val_baseColour_accuracy: 0.4244 - val_baseColour_loss: 2.3843 - val_gender_accuracy: 0.6442 - val_gender_loss: 1.4838 - val_loss: 17.3310 - val_masterCategory_accuracy: 0.6366 - val_masterCategory_loss: 2.8660 - val_subCategory_accuracy: 0.4632 - val_subCategory_loss: 3.8431 - val_usage_accuracy: 0.7936 - val_usage_loss: 1.1101
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - articleType_accuracy: 0.7546 - articleType_loss: 0.7873 - baseColour_accuracy: 0.6064 - baseColour_loss: 1.3430 - gender_accuracy: 0.8553 - gender_loss: 0.3957 - loss: 3.5767 - masterCategory_accuracy: 0.9782 - masterCategory_loss: 0.0784 - subCategory_accuracy: 0.9156 - subCategory_loss: 0.2833 - usage_accuracy: 0.8676 - usage_loss: 0.3686 - val_articleType_accuracy: 0.1786 - val_articleType_loss: 8.1364 - val_baseColour_accuracy: 0.4350 - val_baseColour_loss: 2.7778 - val_gender_accuracy: 0.4418 - val_gender_loss: 3.0966 - val_loss: 27.5249 - val_masterCategory_accuracy: 0.5080 - val_masterCategory_loss: 5.0761 - val_subCategory_accuracy: 0.3252 - val_subCategory_loss: 6.7471 - val_usage_accuracy: 0.8000 - val_usage_loss: 1.2610
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 441s 1s/step - articleType_accuracy: 0.7601 - articleType_loss: 0.7509 - baseColour_accuracy: 0.6105 - baseColour_loss: 1.3108 - gender_accuracy: 0.8639 - gender_loss: 0.3738 - loss: 3.4710 - masterCategory_accuracy: 0.9810 - masterCategory_loss: 0.0727 - subCategory_accuracy: 0.9221 - subCategory_loss: 0.2639 - usage_accuracy: 0.8673 - usage_loss: 0.3637 - val_articleType_accuracy: 0.4556 - val_articleType_loss: 2.7201 - val_baseColour_accuracy: 0.4206 - val_baseColour_loss: 2.6804 - val_gender_accuracy: 0.8048 - val_gender_loss: 0.5925 - val_loss: 10.0041 - val_masterCategory_accuracy: 0.8210 - val_masterCategory_loss: 0.6428 - val_subCategory_accuracy: 0.5572 - val_subCategory_loss: 2.0154 - val_usage_accuracy: 0.7894 - val_usage_loss: 0.9903
# Mean val accuracy for bs=64: 0.6414

# %%
# After loop, save the best model
print(f"\nBest batch size: {best_bs} with mean val accuracy {best_acc:.4f}")
best_model = models[best_bs]

# 1) Ensure the right folder
os.makedirs('models4', exist_ok=True)

# 2) Build a valid filepath with a .keras extension
filepath = f'models4/best_model_bs{best_bs}.h5'

# 3) Save in native Keras format
best_model.save(filepath)

print(f"Saved best model to {filepath}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Best batch size: 16 with mean val accuracy 0.7789
# Saved best model to models4/best_model_bs16.h5

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Assumes: batch_sizes, epochs, attrs, histories are already defined

# 1) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 2) Create the figure
fig, axes = plt.subplots(1, len(batch_sizes), figsize=(18, 5), sharey=True)

for ax, bs in zip(axes, batch_sizes):
    ax.set_title(f"Batch size = {bs}")
    ax.set_xlabel("Epoch")
    if ax is axes[0]:
        ax.set_ylabel("Validation Accuracy")
    
    # Plot each attribute's validation accuracy
    for attr in attrs:
        acc_vals = histories[bs].history[f'val_{attr}_accuracy']
        ax.plot(range(1, epochs+1), acc_vals, marker='o', label=attr)
        
    # Plot mean accuracy
    mean_vals = [
        np.mean([histories[bs].history[f'val_{a}_accuracy'][e] for a in attrs])
        for e in range(epochs)
    ]
    ax.plot(
        range(1, epochs+1),
        mean_vals,
        marker='s',
        linewidth=2,
        color='black',
        label='mean'
    )
    # Annotate mean values
    for e, v in enumerate(mean_vals, start=1):
        ax.text(e, v - 0.005, f"{v:.2f}", ha='center', va='top', fontsize=8)

    ax.set_xticks(range(1, epochs+1))
    ax.legend(loc='lower right', fontsize='small')

plt.tight_layout()

# 3) Save the figure
output_path = 'model_plots/validation_accuracy_by_batch_size.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"Plot saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Plot saved to model_plots/validation_accuracy_by_batch_size.png

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1) First, melt your histories into a tidy DataFrame
records = []
for bs in batch_sizes:
    h = histories[bs].history
    for epoch in range(1, epochs + 1):
        for attr in attrs:
            records.append({
                'batch_size': bs,
                'epoch': epoch,
                'attribute': attr,
                'loss':    h[f'{attr}_loss'][epoch - 1],
                'type':    'train'
            })
            records.append({
                'batch_size': bs,
                'epoch': epoch,
                'attribute': attr,
                'loss':    h[f'val_{attr}_loss'][epoch - 1],
                'type':    'val'
            })
df_loss = pd.DataFrame(records)

# 2) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 3) Draw facets: rows by attribute, col by train/val
g = sns.FacetGrid(
    df_loss,
    row='attribute',
    col='type',
    hue='batch_size',
    sharey=False,      # or True if you want same scale
    height=2.5,
    aspect=2
)
g.map(sns.lineplot, 'epoch', 'loss')
g.add_legend(title='Batch Size')
g.set_axis_labels('Epoch', 'Loss')
g.set_titles(row_template='{row_name}', col_template='{col_name}')
plt.subplots_adjust(hspace=0.3)

# 4) Save the figure
output_path = 'model_plots/loss_by_attribute_and_type.png'
g.fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(g.fig)

print(f"Plot saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Plot saved to model_plots/loss_by_attribute_and_type.png

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1) Melt histories into a tidy DataFrame for accuracy
records = []
for bs in batch_sizes:
    h = histories[bs].history
    for epoch in range(1, epochs + 1):
        for attr in attrs:
            records.append({
                'batch_size': bs,
                'epoch': epoch,
                'attribute': attr,
                'accuracy': h[f'{attr}_accuracy'][epoch - 1],
                'type': 'train'
            })
            records.append({
                'batch_size': bs,
                'epoch': epoch,
                'attribute': attr,
                'accuracy': h[f'val_{attr}_accuracy'][epoch - 1],
                'type': 'val'
            })
df_acc = pd.DataFrame(records)

# 2) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 3) Facet by attribute (rows) and type (cols), hue by batch size
g = sns.FacetGrid(
    df_acc,
    row='attribute',
    col='type',
    hue='batch_size',
    sharey=False,
    height=2.5,
    aspect=2
)
g.map(sns.lineplot, 'epoch', 'accuracy', marker='o')
g.add_legend(title='Batch Size')
g.set_axis_labels('Epoch', 'Accuracy')
g.set_titles(row_template='{row_name}', col_template='{col_name}')
plt.subplots_adjust(hspace=0.3)

# 4) Save the figure
output_path = 'model_plots/accuracy_by_attribute_and_type.png'
g.fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(g.fig)

print(f"Plot saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Plot saved to model_plots/accuracy_by_attribute_and_type.png

# %%
import os
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score

# 1) Ensure output folder exists
os.makedirs('model_reports', exist_ok=True)

# 2) Predict on test set
y_pred = best_model.predict(X_te)

# 3) Generate and save classification reports & accuracy
df_reports = {}
acc_per_attr = {}

for i, a in enumerate(attrs):
    # a) Convert predictions and true labels to integer class indices
    y_p = np.argmax(y_pred[i], axis=1)
    y_t = y_te_int[i]
    
    # b) Build the report as a DataFrame
    report_dict = classification_report(
        y_t, y_p,
        labels=list(range(num_classes[a])),
        target_names=label_encoders[a],
        output_dict=True
    )
    df_rep = pd.DataFrame(report_dict).T
    df_reports[a] = df_rep
    
    # c) Compute overall accuracy
    acc = accuracy_score(y_t, y_p)
    acc_per_attr[a] = acc
    
    # d) Print to console
    print(f"\n=== {a} ===\n", classification_report(
        y_t, y_p,
        labels=list(range(num_classes[a])),
        target_names=label_encoders[a]
    ))
    
    # e) Save the report DataFrame to CSV
    csv_path = f'model_reports/classification_report_{a}.csv'
    df_rep.to_csv(csv_path, index=True)
    print(f"Saved classification report for '{a}' to {csv_path}")

# 4) Save summary of accuracies
df_acc_summary = pd.DataFrame.from_dict(
    acc_per_attr, orient='index', columns=['accuracy']
)
summary_path = 'model_reports/accuracy_summary.csv'
df_acc_summary.to_csv(summary_path)
print(f"\nSaved accuracy summary to {summary_path}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 25s 156ms/step
#
# === gender ===
#                precision    recall  f1-score   support
#
#          Men       0.81      0.95      0.88      2492
#        Women       0.89      0.82      0.85      2122
#         Boys       0.00      0.00      0.00        85
#        Girls       0.25      0.03      0.05        65
#       Unisex       0.64      0.36      0.46       236
#
#     accuracy                           0.84      5000
#    macro avg       0.52      0.43      0.45      5000
# weighted avg       0.82      0.84      0.82      5000
#
# Saved classification report for 'gender' to model_reports/classification_report_gender.csv
#
# === masterCategory ===
#                  precision    recall  f1-score   support
#
#        Apparel       0.99      0.93      0.96      2436
#    Accessories       0.81      0.99      0.89      1233
#       Footwear       1.00      0.97      0.98      1069
#  Personal Care       0.95      0.72      0.82       246
#     Free Items       0.00      0.00      0.00        14
# Sporting Goods       0.00      0.00      0.00         1
#           Home       0.00      0.00      0.00         1
#
#       accuracy                           0.94      5000
#      macro avg       0.54      0.51      0.52      5000
#   weighted avg       0.94      0.94      0.94      5000
#
# Saved classification report for 'masterCategory' to model_reports/classification_report_masterCategory.csv
#
# === subCategory ===
#                            precision    recall  f1-score   support
#
#               Bottomwear       0.88      0.89      0.88       297
#                  Topwear       0.97      0.93      0.95      1750
#                    Socks       0.89      0.88      0.88        73
#                  Watches       0.97      0.82      0.88       282
#                    Shoes       0.92      0.98      0.95       852
#                    Belts       1.00      0.64      0.78        75
#               Flip Flops       0.88      0.55      0.68       105
#                     Bags       0.85      0.85      0.85       339
#                Innerwear       0.89      0.81      0.85       221
#         Shoe Accessories       0.00      0.00      0.00         1
#                Jewellery       0.53      0.95      0.68       133
#                     Lips       0.89      0.50      0.64        48
#                    Saree       0.63      0.98      0.77        45
#                Fragrance       0.68      0.77      0.72        97
#                   Sandal       0.69      0.52      0.59       112
#                    Nails       0.49      0.57      0.53        35
#                    Dress       0.52      0.27      0.36        55
#                  Wallets       0.30      0.97      0.46       105
#                  Eyewear       1.00      0.51      0.67       112
#                 Headwear       0.65      0.50      0.57        34
# Loungewear and Nightwear       0.82      0.24      0.37        59
#                Skin Care       0.00      0.00      0.00        10
#               Free Gifts       0.11      0.07      0.09        14
#                 Mufflers       0.00      0.00      0.00         3
#                     Ties       0.79      1.00      0.88        30
#                   Makeup       0.80      0.09      0.16        44
#              Accessories       1.00      0.38      0.56        13
#                  Scarves       0.80      0.44      0.57         9
#       Beauty Accessories       0.00      0.00      0.00         1
#             Water Bottle       0.00      0.00      0.00         1
#              Apparel Set       0.00      0.00      0.00         7
#                     Skin       0.00      0.00      0.00         6
#                     Eyes       0.00      0.00      0.00         2
#       Sports Accessories       0.00      0.00      0.00         0
#                Cufflinks       0.26      0.82      0.39        11
#         Sports Equipment       0.00      0.00      0.00         1
#                   Stoles       0.33      0.08      0.13        12
#                   Gloves       0.00      0.00      0.00         2
#                     Hair       0.00      0.00      0.00         1
#                 Perfumes       0.00      0.00      0.00         0
#          Home Furnishing       0.00      0.00      0.00         1
#            Bath and Body       0.00      0.00      0.00         2
#                Umbrellas       0.00      0.00      0.00         0
#               Wristbands       0.00      0.00      0.00         0
#                 Vouchers       0.00      0.00      0.00         0
#
#                micro avg       0.84      0.84      0.84      5000
#                macro avg       0.43      0.38      0.37      5000
#             weighted avg       0.87      0.84      0.84      5000
#
# Saved classification report for 'subCategory' to model_reports/classification_report_subCategory.csv
#
# === articleType ===
#                             precision    recall  f1-score   support
#
#               Track Pants       0.42      0.86      0.56        29
#                   Tshirts       0.94      0.53      0.68       831
#                    Shirts       0.47      0.95      0.63       364
#                     Socks       0.93      0.87      0.90        71
#                   Watches       0.96      0.85      0.90       282
#              Casual Shoes       0.55      0.81      0.65       313
#                     Belts       1.00      0.74      0.85        74
#                Flip Flops       0.88      0.55      0.67       106
#                  Handbags       0.91      0.82      0.86       189
#                      Tops       0.46      0.59      0.52       203
#                       Bra       0.77      0.92      0.84        60
#          Shoe Accessories       0.00      0.00      0.00         1
#               Sweatshirts       0.00      0.00      0.00        32
#              Formal Shoes       0.50      0.96      0.66        72
#                  Bracelet       0.09      0.56      0.16         9
#                  Lipstick       0.88      0.25      0.39        28
#                     Flats       0.00      0.00      0.00        61
#                    Kurtas       0.86      0.88      0.87       188
#                 Waistcoat       0.00      0.00      0.00         0
#              Sports Shoes       0.96      0.38      0.55       248
#                    Shorts       0.76      0.54      0.63        71
#                    Briefs       0.94      0.78      0.85       101
#                    Sarees       0.56      1.00      0.72        45
#     Perfume and Body Mist       0.38      0.84      0.53        61
#                     Heels       0.71      0.77      0.74       157
#                   Sandals       0.64      0.68      0.66       106
#                   Pendant       0.20      0.04      0.06        26
#               Nail Polish       0.35      0.57      0.43        35
#                Laptop Bag       0.00      0.00      0.00         7
#               Rain Jacket       0.00      0.00      0.00         2
#                   Dresses       0.55      0.42      0.48        50
#                    Skirts       0.50      0.16      0.24        19
#                   Wallets       0.25      0.99      0.40       105
#                   Blazers       0.00      0.00      0.00         1
#                      Ring       0.05      0.06      0.05        17
#                Sunglasses       1.00      0.55      0.71       112
#                  Clutches       0.00      0.00      0.00        37
#                     Shrug       0.00      0.00      0.00         0
#                      Caps       0.57      0.39      0.46        33
#           Innerwear Vests       0.74      0.52      0.61        33
#                  Earrings       0.44      0.87      0.58        45
#                  Trousers       0.62      0.60      0.61        50
#                    Boxers       1.00      0.67      0.80         3
#                 Backpacks       0.70      0.99      0.82        83
#                     Jeans       0.60      0.85      0.71        75
#             Jewellery Set       0.00      0.00      0.00         8
#                   Dupatta       0.00      0.00      0.00        13
#                    Capris       0.00      0.00      0.00        13
#                 Bath Robe       0.00      0.00      0.00         2
#                    Tunics       0.00      0.00      0.00        24
#                   Jackets       0.00      0.00      0.00        28
#              Lounge Pants       0.00      0.00      0.00         7
#    Face Wash and Cleanser       0.00      0.00      0.00         4
#       Necklace and Chains       0.78      0.30      0.44        23
#                Duffel Bag       0.00      0.00      0.00        11
#            Sports Sandals       0.00      0.00      0.00         6
#                 Deodorant       0.00      0.00      0.00        31
#                  Sweaters       0.33      0.10      0.15        31
#                Free Gifts       0.00      0.00      0.00        13
#                Tracksuits       0.00      0.00      0.00         3
#                Shoe Laces       0.00      0.00      0.00         0
#                     Trunk       0.64      0.60      0.62        15
#                  Mufflers       0.00      0.00      0.00         3
#                    Bangle       0.00      0.00      0.00         5
#                      Ties       0.82      1.00      0.90        31
#     Highlighter and Blush       0.00      0.00      0.00         6
#          Travel Accessory       0.00      0.00      0.00         3
#                  Lip Care       0.00      0.00      0.00         0
#                   Scarves       0.38      0.33      0.35         9
#             Messenger Bag       0.00      0.00      0.00         7
#                   Compact       0.50      0.14      0.22         7
#               Night suits       1.00      0.06      0.12        16
#                  Leggings       0.50      0.14      0.21        22
#                 Eye Cream       0.00      0.00      0.00         2
#                 Lip Gloss       0.33      0.10      0.15        10
#                    Kurtis       0.00      0.00      0.00        24
#        Accessory Gift Set       1.00      0.67      0.80         6
#          Beauty Accessory       0.00      0.00      0.00         1
#                  Jumpsuit       0.00      0.00      0.00         5
#                Nightdress       0.69      0.27      0.39        33
#              Water Bottle       0.00      0.00      0.00         2
#                Kurta Sets       0.00      0.00      0.00         7
#         Face Moisturisers       0.00      0.00      0.00         3
#                Suspenders       1.00      0.80      0.89         5
#              Mobile Pouch       0.00      0.00      0.00         6
#                 Lip Liner       0.00      0.00      0.00         8
#                      Robe       0.00      0.00      0.00         0
#                 Stockings       0.00      0.00      0.00         3
#        Kajal and Eyeliner       1.00      0.08      0.15        12
#                 Eyeshadow       0.00      0.00      0.00         5
#                  Headband       0.00      0.00      0.00         1
#                   Patiala       0.00      0.00      0.00         3
#                 Camisoles       0.00      0.00      0.00         7
#                    Tights       0.00      0.00      0.00         1
#            Lounge Tshirts       0.00      0.00      0.00         0
#        Fragrance Gift Set       0.00      0.00      0.00         5
# Face Scrub and Exfoliator       0.00      0.00      0.00         1
#             Lounge Shorts       0.00      0.00      0.00         0
#                Baby Dolls       0.00      0.00      0.00         1
#     Foundation and Primer       0.33      0.08      0.13        12
#                Wristbands       0.00      0.00      0.00         0
#        Salwar and Dupatta       0.00      0.00      0.00         1
#                  Swimwear       0.00      0.00      0.00         0
#             Tablet Sleeve       0.00      0.00      0.00         0
#        Ties and Cufflinks       0.00      0.00      0.00         0
#                 Footballs       0.00      0.00      0.00         0
#                    Stoles       0.17      0.17      0.17        12
#                 Shapewear       0.00      0.00      0.00         2
#                    Salwar       0.00      0.00      0.00         2
#                 Cufflinks       0.22      0.82      0.35        11
#                 Concealer       0.00      0.00      0.00         2
#                   Rompers       0.00      0.00      0.00         3
#                  Jeggings       0.00      0.00      0.00         2
#                    Gloves       0.00      0.00      0.00         2
#                 Sunscreen       0.00      0.00      0.00         0
#                   Booties       0.00      0.00      0.00         2
#             Mask and Peel       0.00      0.00      0.00         4
#               Waist Pouch       0.00      0.00      0.00         1
#                 Rucksacks       0.00      0.00      0.00         1
#               Basketballs       0.00      0.00      0.00         1
#               Hair Colour       0.00      0.00      0.00         1
#                  Churidar       0.00      0.00      0.00         3
#              Clothing Set       0.00      0.00      0.00         0
#                   Mascara       0.00      0.00      0.00         1
#             Nehru Jackets       0.00      0.00      0.00         1
#            Cushion Covers       0.00      0.00      0.00         1
#                 Key chain       0.00      0.00      0.00         0
#                     Toner       0.00      0.00      0.00         1
#               Lip Plumper       0.00      0.00      0.00         2
#           Nail Essentials       0.00      0.00      0.00         2
#                 Umbrellas       0.00      0.00      0.00         0
#        Face Serum and Gel       0.00      0.00      0.00         1
#               Body Lotion       0.00      0.00      0.00         0
#            Makeup Remover       0.00      0.00      0.00         1
#             Rain Trousers       0.00      0.00      0.00         0
#                       Hat       0.00      0.00      0.00         0
#               Trolley Bag       0.00      0.00      0.00         0
#             Lehenga Choli       0.00      0.00      0.00         1
#                      Ipad       0.00      0.00      0.00         0
#
#                 micro avg       0.62      0.62      0.62      5000
#                 macro avg       0.24      0.21      0.20      5000
#              weighted avg       0.67      0.62      0.60      5000
#
# Saved classification report for 'articleType' to model_reports/classification_report_articleType.csv
#
# === baseColour ===
#                     precision    recall  f1-score   support
#
#             Black       0.66      0.88      0.76      1049
#              Grey       0.53      0.34      0.42       303
#             Green       0.54      0.73      0.62       251
#         Navy Blue       0.57      0.13      0.21       194
#              Blue       0.55      0.81      0.65       553
#             White       0.69      0.68      0.68       679
#             Beige       0.24      0.35      0.29        79
#            Bronze       0.00      0.00      0.00        12
#             Brown       0.70      0.52      0.59       417
#            Copper       0.00      0.00      0.00         5
#              Pink       0.55      0.43      0.48       213
#         Off White       0.00      0.00      0.00        19
#            Maroon       0.09      0.02      0.03        58
#            Purple       0.71      0.34      0.46       177
#             Khaki       0.00      0.00      0.00        17
#            Silver       0.48      0.43      0.45       138
#            Orange       0.70      0.23      0.35        69
#      Coffee Brown       0.00      0.00      0.00         4
#               Red       0.46      0.85      0.60       248
#          Charcoal       0.00      0.00      0.00        16
#              Gold       0.22      0.41      0.29        68
#             Steel       0.00      0.00      0.00        33
#             Multi       0.00      0.00      0.00        42
#           Magenta       0.00      0.00      0.00        23
#         Sea Green       0.00      0.00      0.00         2
#             Cream       0.00      0.00      0.00        40
#            Yellow       0.50      0.73      0.59        84
#             Olive       0.33      0.05      0.08        42
#      Grey Melange       0.00      0.00      0.00        15
#              Teal       0.00      0.00      0.00         5
#          Burgundy       0.00      0.00      0.00         5
#             Peach       1.00      0.04      0.08        25
#              Rust       0.00      0.00      0.00         6
#              Skin       0.17      0.04      0.06        25
#    Turquoise Blue       0.00      0.00      0.00        10
#               Tan       0.00      0.00      0.00        15
#          Lavender       0.00      0.00      0.00        28
#          Metallic       0.00      0.00      0.00         5
#           Mustard       0.00      0.00      0.00        11
#             Mauve       0.00      0.00      0.00         5
#              Nude       0.00      0.00      0.00         6
#              Rose       0.00      0.00      0.00         1
#    Mushroom Brown       0.00      0.00      0.00         1
#             Taupe       0.00      0.00      0.00         1
#        Lime Green       0.00      0.00      0.00         0
# Fluorescent Green       0.00      0.00      0.00         1
#
#         micro avg       0.58      0.58      0.58      5000
#         macro avg       0.21      0.17      0.17      5000
#      weighted avg       0.55      0.58      0.54      5000
#
# Saved classification report for 'baseColour' to model_reports/classification_report_baseColour.csv
#
# === usage ===
#                precision    recall  f1-score   support
#
#       Casual       0.86      0.97      0.91      3871
#       Ethnic       0.94      0.74      0.83       329
#       Sports       0.96      0.20      0.33       501
#       Formal       0.62      0.74      0.67       257
# Smart Casual       0.00      0.00      0.00         6
#        Party       0.00      0.00      0.00         3
#       Travel       0.00      0.00      0.00         1
#         Home       0.00      0.00      0.00         1
#
#    micro avg       0.85      0.86      0.86      4969
#    macro avg       0.42      0.33      0.34      4969
# weighted avg       0.86      0.86      0.83      4969
#
# Saved classification report for 'usage' to model_reports/classification_report_usage.csv
#
# Saved accuracy summary to model_reports/accuracy_summary.csv
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import classification_report, accuracy_score

# Assuming: attrs, y_te_int, y_pred, label_encoders, num_classes are defined

for attr in attrs:
    i = attrs.index(attr)
    y_true = y_te_int[i]
    y_pred_cls = np.argmax(y_pred[i], axis=1)
    
    print(f"\n=== Classification Report: {attr} ===\n")
    print(classification_report(
        y_true,
        y_pred_cls,
        labels=list(range(num_classes[attr])),
        target_names=label_encoders[attr]
    ))
    print(f"Accuracy for {attr}: {accuracy_score(y_true, y_pred_cls):.4f}")
# Out:
# === Classification Report: gender ===
#
#               precision    recall  f1-score   support
#
#          Men       0.81      0.95      0.88      2492
#        Women       0.89      0.82      0.85      2122
#         Boys       0.00      0.00      0.00        85
#        Girls       0.25      0.03      0.05        65
#       Unisex       0.64      0.36      0.46       236
#
#     accuracy                           0.84      5000
#    macro avg       0.52      0.43      0.45      5000
# weighted avg       0.82      0.84      0.82      5000
#
# Accuracy for gender: 0.8374
#
# === Classification Report: masterCategory ===
#
#                 precision    recall  f1-score   support
#
#        Apparel       0.99      0.93      0.96      2436
#    Accessories       0.81      0.99      0.89      1233
#       Footwear       1.00      0.97      0.98      1069
#  Personal Care       0.95      0.72      0.82       246
#     Free Items       0.00      0.00      0.00        14
# Sporting Goods       0.00      0.00      0.00         1
#           Home       0.00      0.00      0.00         1
#
#       accuracy                           0.94      5000
#      macro avg       0.54      0.51      0.52      5000
#   weighted avg       0.94      0.94      0.94      5000
#
# Accuracy for masterCategory: 0.9366
#
# === Classification Report: subCategory ===
#
#                           precision    recall  f1-score   support
#
#               Bottomwear       0.88      0.89      0.88       297
#                  Topwear       0.97      0.93      0.95      1750
#                    Socks       0.89      0.88      0.88        73
#                  Watches       0.97      0.82      0.88       282
#                    Shoes       0.92      0.98      0.95       852
#                    Belts       1.00      0.64      0.78        75
#               Flip Flops       0.88      0.55      0.68       105
#                     Bags       0.85      0.85      0.85       339
#                Innerwear       0.89      0.81      0.85       221
#         Shoe Accessories       0.00      0.00      0.00         1
#                Jewellery       0.53      0.95      0.68       133
#                     Lips       0.89      0.50      0.64        48
#                    Saree       0.63      0.98      0.77        45
#                Fragrance       0.68      0.77      0.72        97
#                   Sandal       0.69      0.52      0.59       112
#                    Nails       0.49      0.57      0.53        35
#                    Dress       0.52      0.27      0.36        55
#                  Wallets       0.30      0.97      0.46       105
#                  Eyewear       1.00      0.51      0.67       112
#                 Headwear       0.65      0.50      0.57        34
# Loungewear and Nightwear       0.82      0.24      0.37        59
#                Skin Care       0.00      0.00      0.00        10
#               Free Gifts       0.11      0.07      0.09        14
#                 Mufflers       0.00      0.00      0.00         3
#                     Ties       0.79      1.00      0.88        30
#                   Makeup       0.80      0.09      0.16        44
#              Accessories       1.00      0.38      0.56        13
#                  Scarves       0.80      0.44      0.57         9
#       Beauty Accessories       0.00      0.00      0.00         1
#             Water Bottle       0.00      0.00      0.00         1
#              Apparel Set       0.00      0.00      0.00         7
#                     Skin       0.00      0.00      0.00         6
#                     Eyes       0.00      0.00      0.00         2
#       Sports Accessories       0.00      0.00      0.00         0
#                Cufflinks       0.26      0.82      0.39        11
#         Sports Equipment       0.00      0.00      0.00         1
#                   Stoles       0.33      0.08      0.13        12
#                   Gloves       0.00      0.00      0.00         2
#                     Hair       0.00      0.00      0.00         1
#                 Perfumes       0.00      0.00      0.00         0
#          Home Furnishing       0.00      0.00      0.00         1
#            Bath and Body       0.00      0.00      0.00         2
#                Umbrellas       0.00      0.00      0.00         0
#               Wristbands       0.00      0.00      0.00         0
#                 Vouchers       0.00      0.00      0.00         0
#
#                micro avg       0.84      0.84      0.84      5000
#                macro avg       0.43      0.38      0.37      5000
#             weighted avg       0.87      0.84      0.84      5000
#
# Accuracy for subCategory: 0.8422
#
# === Classification Report: articleType ===
#
#                            precision    recall  f1-score   support
#
#               Track Pants       0.42      0.86      0.56        29
#                   Tshirts       0.94      0.53      0.68       831
#                    Shirts       0.47      0.95      0.63       364
#                     Socks       0.93      0.87      0.90        71
#                   Watches       0.96      0.85      0.90       282
#              Casual Shoes       0.55      0.81      0.65       313
#                     Belts       1.00      0.74      0.85        74
#                Flip Flops       0.88      0.55      0.67       106
#                  Handbags       0.91      0.82      0.86       189
#                      Tops       0.46      0.59      0.52       203
#                       Bra       0.77      0.92      0.84        60
#          Shoe Accessories       0.00      0.00      0.00         1
#               Sweatshirts       0.00      0.00      0.00        32
#              Formal Shoes       0.50      0.96      0.66        72
#                  Bracelet       0.09      0.56      0.16         9
#                  Lipstick       0.88      0.25      0.39        28
#                     Flats       0.00      0.00      0.00        61
#                    Kurtas       0.86      0.88      0.87       188
#                 Waistcoat       0.00      0.00      0.00         0
#              Sports Shoes       0.96      0.38      0.55       248
#                    Shorts       0.76      0.54      0.63        71
#                    Briefs       0.94      0.78      0.85       101
#                    Sarees       0.56      1.00      0.72        45
#     Perfume and Body Mist       0.38      0.84      0.53        61
#                     Heels       0.71      0.77      0.74       157
#                   Sandals       0.64      0.68      0.66       106
#                   Pendant       0.20      0.04      0.06        26
#               Nail Polish       0.35      0.57      0.43        35
#                Laptop Bag       0.00      0.00      0.00         7
#               Rain Jacket       0.00      0.00      0.00         2
#                   Dresses       0.55      0.42      0.48        50
#                    Skirts       0.50      0.16      0.24        19
#                   Wallets       0.25      0.99      0.40       105
#                   Blazers       0.00      0.00      0.00         1
#                      Ring       0.05      0.06      0.05        17
#                Sunglasses       1.00      0.55      0.71       112
#                  Clutches       0.00      0.00      0.00        37
#                     Shrug       0.00      0.00      0.00         0
#                      Caps       0.57      0.39      0.46        33
#           Innerwear Vests       0.74      0.52      0.61        33
#                  Earrings       0.44      0.87      0.58        45
#                  Trousers       0.62      0.60      0.61        50
#                    Boxers       1.00      0.67      0.80         3
#                 Backpacks       0.70      0.99      0.82        83
#                     Jeans       0.60      0.85      0.71        75
#             Jewellery Set       0.00      0.00      0.00         8
#                   Dupatta       0.00      0.00      0.00        13
#                    Capris       0.00      0.00      0.00        13
#                 Bath Robe       0.00      0.00      0.00         2
#                    Tunics       0.00      0.00      0.00        24
#                   Jackets       0.00      0.00      0.00        28
#              Lounge Pants       0.00      0.00      0.00         7
#    Face Wash and Cleanser       0.00      0.00      0.00         4
#       Necklace and Chains       0.78      0.30      0.44        23
#                Duffel Bag       0.00      0.00      0.00        11
#            Sports Sandals       0.00      0.00      0.00         6
#                 Deodorant       0.00      0.00      0.00        31
#                  Sweaters       0.33      0.10      0.15        31
#                Free Gifts       0.00      0.00      0.00        13
#                Tracksuits       0.00      0.00      0.00         3
#                Shoe Laces       0.00      0.00      0.00         0
#                     Trunk       0.64      0.60      0.62        15
#                  Mufflers       0.00      0.00      0.00         3
#                    Bangle       0.00      0.00      0.00         5
#                      Ties       0.82      1.00      0.90        31
#     Highlighter and Blush       0.00      0.00      0.00         6
#          Travel Accessory       0.00      0.00      0.00         3
#                  Lip Care       0.00      0.00      0.00         0
#                   Scarves       0.38      0.33      0.35         9
#             Messenger Bag       0.00      0.00      0.00         7
#                   Compact       0.50      0.14      0.22         7
#               Night suits       1.00      0.06      0.12        16
#                  Leggings       0.50      0.14      0.21        22
#                 Eye Cream       0.00      0.00      0.00         2
#                 Lip Gloss       0.33      0.10      0.15        10
#                    Kurtis       0.00      0.00      0.00        24
#        Accessory Gift Set       1.00      0.67      0.80         6
#          Beauty Accessory       0.00      0.00      0.00         1
#                  Jumpsuit       0.00      0.00      0.00         5
#                Nightdress       0.69      0.27      0.39        33
#              Water Bottle       0.00      0.00      0.00         2
#                Kurta Sets       0.00      0.00      0.00         7
#         Face Moisturisers       0.00      0.00      0.00         3
#                Suspenders       1.00      0.80      0.89         5
#              Mobile Pouch       0.00      0.00      0.00         6
#                 Lip Liner       0.00      0.00      0.00         8
#                      Robe       0.00      0.00      0.00         0
#                 Stockings       0.00      0.00      0.00         3
#        Kajal and Eyeliner       1.00      0.08      0.15        12
#                 Eyeshadow       0.00      0.00      0.00         5
#                  Headband       0.00      0.00      0.00         1
#                   Patiala       0.00      0.00      0.00         3
#                 Camisoles       0.00      0.00      0.00         7
#                    Tights       0.00      0.00      0.00         1
#            Lounge Tshirts       0.00      0.00      0.00         0
#        Fragrance Gift Set       0.00      0.00      0.00         5
# Face Scrub and Exfoliator       0.00      0.00      0.00         1
#             Lounge Shorts       0.00      0.00      0.00         0
#                Baby Dolls       0.00      0.00      0.00         1
#     Foundation and Primer       0.33      0.08      0.13        12
#                Wristbands       0.00      0.00      0.00         0
#        Salwar and Dupatta       0.00      0.00      0.00         1
#                  Swimwear       0.00      0.00      0.00         0
#             Tablet Sleeve       0.00      0.00      0.00         0
#        Ties and Cufflinks       0.00      0.00      0.00         0
#                 Footballs       0.00      0.00      0.00         0
#                    Stoles       0.17      0.17      0.17        12
#                 Shapewear       0.00      0.00      0.00         2
#                    Salwar       0.00      0.00      0.00         2
#                 Cufflinks       0.22      0.82      0.35        11
#                 Concealer       0.00      0.00      0.00         2
#                   Rompers       0.00      0.00      0.00         3
#                  Jeggings       0.00      0.00      0.00         2
#                    Gloves       0.00      0.00      0.00         2
#                 Sunscreen       0.00      0.00      0.00         0
#                   Booties       0.00      0.00      0.00         2
#             Mask and Peel       0.00      0.00      0.00         4
#               Waist Pouch       0.00      0.00      0.00         1
#                 Rucksacks       0.00      0.00      0.00         1
#               Basketballs       0.00      0.00      0.00         1
#               Hair Colour       0.00      0.00      0.00         1
#                  Churidar       0.00      0.00      0.00         3
#              Clothing Set       0.00      0.00      0.00         0
#                   Mascara       0.00      0.00      0.00         1
#             Nehru Jackets       0.00      0.00      0.00         1
#            Cushion Covers       0.00      0.00      0.00         1
#                 Key chain       0.00      0.00      0.00         0
#                     Toner       0.00      0.00      0.00         1
#               Lip Plumper       0.00      0.00      0.00         2
#           Nail Essentials       0.00      0.00      0.00         2
#                 Umbrellas       0.00      0.00      0.00         0
#        Face Serum and Gel       0.00      0.00      0.00         1
#               Body Lotion       0.00      0.00      0.00         0
#            Makeup Remover       0.00      0.00      0.00         1
#             Rain Trousers       0.00      0.00      0.00         0
#                       Hat       0.00      0.00      0.00         0
#               Trolley Bag       0.00      0.00      0.00         0
#             Lehenga Choli       0.00      0.00      0.00         1
#                      Ipad       0.00      0.00      0.00         0
#
#                 micro avg       0.62      0.62      0.62      5000
#                 macro avg       0.24      0.21      0.20      5000
#              weighted avg       0.67      0.62      0.60      5000
#
# Accuracy for articleType: 0.6200
#
# === Classification Report: baseColour ===
#
#                    precision    recall  f1-score   support
#
#             Black       0.66      0.88      0.76      1049
#              Grey       0.53      0.34      0.42       303
#             Green       0.54      0.73      0.62       251
#         Navy Blue       0.57      0.13      0.21       194
#              Blue       0.55      0.81      0.65       553
#             White       0.69      0.68      0.68       679
#             Beige       0.24      0.35      0.29        79
#            Bronze       0.00      0.00      0.00        12
#             Brown       0.70      0.52      0.59       417
#            Copper       0.00      0.00      0.00         5
#              Pink       0.55      0.43      0.48       213
#         Off White       0.00      0.00      0.00        19
#            Maroon       0.09      0.02      0.03        58
#            Purple       0.71      0.34      0.46       177
#             Khaki       0.00      0.00      0.00        17
#            Silver       0.48      0.43      0.45       138
#            Orange       0.70      0.23      0.35        69
#      Coffee Brown       0.00      0.00      0.00         4
#               Red       0.46      0.85      0.60       248
#          Charcoal       0.00      0.00      0.00        16
#              Gold       0.22      0.41      0.29        68
#             Steel       0.00      0.00      0.00        33
#             Multi       0.00      0.00      0.00        42
#           Magenta       0.00      0.00      0.00        23
#         Sea Green       0.00      0.00      0.00         2
#             Cream       0.00      0.00      0.00        40
#            Yellow       0.50      0.73      0.59        84
#             Olive       0.33      0.05      0.08        42
#      Grey Melange       0.00      0.00      0.00        15
#              Teal       0.00      0.00      0.00         5
#          Burgundy       0.00      0.00      0.00         5
#             Peach       1.00      0.04      0.08        25
#              Rust       0.00      0.00      0.00         6
#              Skin       0.17      0.04      0.06        25
#    Turquoise Blue       0.00      0.00      0.00        10
#               Tan       0.00      0.00      0.00        15
#          Lavender       0.00      0.00      0.00        28
#          Metallic       0.00      0.00      0.00         5
#           Mustard       0.00      0.00      0.00        11
#             Mauve       0.00      0.00      0.00         5
#              Nude       0.00      0.00      0.00         6
#              Rose       0.00      0.00      0.00         1
#    Mushroom Brown       0.00      0.00      0.00         1
#             Taupe       0.00      0.00      0.00         1
#        Lime Green       0.00      0.00      0.00         0
# Fluorescent Green       0.00      0.00      0.00         1
#
#         micro avg       0.58      0.58      0.58      5000
#         macro avg       0.21      0.17      0.17      5000
#      weighted avg       0.55      0.58      0.54      5000
#
# Accuracy for baseColour: 0.5826
#
# === Classification Report: usage ===
#
#               precision    recall  f1-score   support
#
#       Casual       0.86      0.97      0.91      3871
#       Ethnic       0.94      0.74      0.83       329
#       Sports       0.96      0.20      0.33       501
#       Formal       0.62      0.74      0.67       257
# Smart Casual       0.00      0.00      0.00         6
#        Party       0.00      0.00      0.00         3
#       Travel       0.00      0.00      0.00         1
#         Home       0.00      0.00      0.00         1
#
#    micro avg       0.85      0.86      0.86      4969
#    macro avg       0.42      0.33      0.34      4969
# weighted avg       0.86      0.86      0.83      4969
#
# Accuracy for usage: 0.8548
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import numpy as np
from sklearn.metrics import classification_report, accuracy_score

# 1) Ensure output folder exists
os.makedirs('model_reports', exist_ok=True)

# 2) Loop through each attribute, print and save reports
accuracy_summary = {}

for attr in attrs:
    i = attrs.index(attr)
    y_true = y_te_int[i]
    y_pred_cls = np.argmax(y_pred[i], axis=1)
    
    # a) Generate the text report
    report_text = classification_report(
        y_true,
        y_pred_cls,
        labels=list(range(num_classes[attr])),
        target_names=label_encoders[attr]
    )
    accuracy = accuracy_score(y_true, y_pred_cls)
    accuracy_summary[attr] = accuracy
    
    # b) Print to console
    print(f"\n=== Classification Report: {attr} ===\n")
    print(report_text)
    print(f"Accuracy for {attr}: {accuracy:.4f}")
    
    # c) Save the report to a .txt file
    txt_path = f'model_reports/classification_report_{attr}.txt'
    with open(txt_path, 'w') as f:
        f.write(f"Classification Report for '{attr}'\n\n")
        f.write(report_text)
        f.write(f"\nAccuracy: {accuracy:.4f}\n")
    print(f"Saved report to {txt_path}")

# 3) Save overall accuracies to CSV
import pandas as pd

df_acc_summary = pd.DataFrame.from_dict(
    accuracy_summary, orient='index', columns=['accuracy']
)
csv_path = 'model_reports/accuracy_summary.csv'
df_acc_summary.to_csv(csv_path, index_label='attribute')
print(f"\nSaved accuracy summary to {csv_path}")
# Out:
# === Classification Report: gender ===
#
#               precision    recall  f1-score   support
#
#          Men       0.81      0.95      0.88      2492
#        Women       0.89      0.82      0.85      2122
#         Boys       0.00      0.00      0.00        85
#        Girls       0.25      0.03      0.05        65
#       Unisex       0.64      0.36      0.46       236
#
#     accuracy                           0.84      5000
#    macro avg       0.52      0.43      0.45      5000
# weighted avg       0.82      0.84      0.82      5000
#
# Accuracy for gender: 0.8374
# Saved report to model_reports/classification_report_gender.txt
#
# === Classification Report: masterCategory ===
#
#                 precision    recall  f1-score   support
#
#        Apparel       0.99      0.93      0.96      2436
#    Accessories       0.81      0.99      0.89      1233
#       Footwear       1.00      0.97      0.98      1069
#  Personal Care       0.95      0.72      0.82       246
#     Free Items       0.00      0.00      0.00        14
# Sporting Goods       0.00      0.00      0.00         1
#           Home       0.00      0.00      0.00         1
#
#       accuracy                           0.94      5000
#      macro avg       0.54      0.51      0.52      5000
#   weighted avg       0.94      0.94      0.94      5000
#
# Accuracy for masterCategory: 0.9366
# Saved report to model_reports/classification_report_masterCategory.txt
#
# === Classification Report: subCategory ===
#
#                           precision    recall  f1-score   support
#
#               Bottomwear       0.88      0.89      0.88       297
#                  Topwear       0.97      0.93      0.95      1750
#                    Socks       0.89      0.88      0.88        73
#                  Watches       0.97      0.82      0.88       282
#                    Shoes       0.92      0.98      0.95       852
#                    Belts       1.00      0.64      0.78        75
#               Flip Flops       0.88      0.55      0.68       105
#                     Bags       0.85      0.85      0.85       339
#                Innerwear       0.89      0.81      0.85       221
#         Shoe Accessories       0.00      0.00      0.00         1
#                Jewellery       0.53      0.95      0.68       133
#                     Lips       0.89      0.50      0.64        48
#                    Saree       0.63      0.98      0.77        45
#                Fragrance       0.68      0.77      0.72        97
#                   Sandal       0.69      0.52      0.59       112
#                    Nails       0.49      0.57      0.53        35
#                    Dress       0.52      0.27      0.36        55
#                  Wallets       0.30      0.97      0.46       105
#                  Eyewear       1.00      0.51      0.67       112
#                 Headwear       0.65      0.50      0.57        34
# Loungewear and Nightwear       0.82      0.24      0.37        59
#                Skin Care       0.00      0.00      0.00        10
#               Free Gifts       0.11      0.07      0.09        14
#                 Mufflers       0.00      0.00      0.00         3
#                     Ties       0.79      1.00      0.88        30
#                   Makeup       0.80      0.09      0.16        44
#              Accessories       1.00      0.38      0.56        13
#                  Scarves       0.80      0.44      0.57         9
#       Beauty Accessories       0.00      0.00      0.00         1
#             Water Bottle       0.00      0.00      0.00         1
#              Apparel Set       0.00      0.00      0.00         7
#                     Skin       0.00      0.00      0.00         6
#                     Eyes       0.00      0.00      0.00         2
#       Sports Accessories       0.00      0.00      0.00         0
#                Cufflinks       0.26      0.82      0.39        11
#         Sports Equipment       0.00      0.00      0.00         1
#                   Stoles       0.33      0.08      0.13        12
#                   Gloves       0.00      0.00      0.00         2
#                     Hair       0.00      0.00      0.00         1
#                 Perfumes       0.00      0.00      0.00         0
#          Home Furnishing       0.00      0.00      0.00         1
#            Bath and Body       0.00      0.00      0.00         2
#                Umbrellas       0.00      0.00      0.00         0
#               Wristbands       0.00      0.00      0.00         0
#                 Vouchers       0.00      0.00      0.00         0
#
#                micro avg       0.84      0.84      0.84      5000
#                macro avg       0.43      0.38      0.37      5000
#             weighted avg       0.87      0.84      0.84      5000
#
# Accuracy for subCategory: 0.8422
# Saved report to model_reports/classification_report_subCategory.txt
#
# === Classification Report: articleType ===
#
#                            precision    recall  f1-score   support
#
#               Track Pants       0.42      0.86      0.56        29
#                   Tshirts       0.94      0.53      0.68       831
#                    Shirts       0.47      0.95      0.63       364
#                     Socks       0.93      0.87      0.90        71
#                   Watches       0.96      0.85      0.90       282
#              Casual Shoes       0.55      0.81      0.65       313
#                     Belts       1.00      0.74      0.85        74
#                Flip Flops       0.88      0.55      0.67       106
#                  Handbags       0.91      0.82      0.86       189
#                      Tops       0.46      0.59      0.52       203
#                       Bra       0.77      0.92      0.84        60
#          Shoe Accessories       0.00      0.00      0.00         1
#               Sweatshirts       0.00      0.00      0.00        32
#              Formal Shoes       0.50      0.96      0.66        72
#                  Bracelet       0.09      0.56      0.16         9
#                  Lipstick       0.88      0.25      0.39        28
#                     Flats       0.00      0.00      0.00        61
#                    Kurtas       0.86      0.88      0.87       188
#                 Waistcoat       0.00      0.00      0.00         0
#              Sports Shoes       0.96      0.38      0.55       248
#                    Shorts       0.76      0.54      0.63        71
#                    Briefs       0.94      0.78      0.85       101
#                    Sarees       0.56      1.00      0.72        45
#     Perfume and Body Mist       0.38      0.84      0.53        61
#                     Heels       0.71      0.77      0.74       157
#                   Sandals       0.64      0.68      0.66       106
#                   Pendant       0.20      0.04      0.06        26
#               Nail Polish       0.35      0.57      0.43        35
#                Laptop Bag       0.00      0.00      0.00         7
#               Rain Jacket       0.00      0.00      0.00         2
#                   Dresses       0.55      0.42      0.48        50
#                    Skirts       0.50      0.16      0.24        19
#                   Wallets       0.25      0.99      0.40       105
#                   Blazers       0.00      0.00      0.00         1
#                      Ring       0.05      0.06      0.05        17
#                Sunglasses       1.00      0.55      0.71       112
#                  Clutches       0.00      0.00      0.00        37
#                     Shrug       0.00      0.00      0.00         0
#                      Caps       0.57      0.39      0.46        33
#           Innerwear Vests       0.74      0.52      0.61        33
#                  Earrings       0.44      0.87      0.58        45
#                  Trousers       0.62      0.60      0.61        50
#                    Boxers       1.00      0.67      0.80         3
#                 Backpacks       0.70      0.99      0.82        83
#                     Jeans       0.60      0.85      0.71        75
#             Jewellery Set       0.00      0.00      0.00         8
#                   Dupatta       0.00      0.00      0.00        13
#                    Capris       0.00      0.00      0.00        13
#                 Bath Robe       0.00      0.00      0.00         2
#                    Tunics       0.00      0.00      0.00        24
#                   Jackets       0.00      0.00      0.00        28
#              Lounge Pants       0.00      0.00      0.00         7
#    Face Wash and Cleanser       0.00      0.00      0.00         4
#       Necklace and Chains       0.78      0.30      0.44        23
#                Duffel Bag       0.00      0.00      0.00        11
#            Sports Sandals       0.00      0.00      0.00         6
#                 Deodorant       0.00      0.00      0.00        31
#                  Sweaters       0.33      0.10      0.15        31
#                Free Gifts       0.00      0.00      0.00        13
#                Tracksuits       0.00      0.00      0.00         3
#                Shoe Laces       0.00      0.00      0.00         0
#                     Trunk       0.64      0.60      0.62        15
#                  Mufflers       0.00      0.00      0.00         3
#                    Bangle       0.00      0.00      0.00         5
#                      Ties       0.82      1.00      0.90        31
#     Highlighter and Blush       0.00      0.00      0.00         6
#          Travel Accessory       0.00      0.00      0.00         3
#                  Lip Care       0.00      0.00      0.00         0
#                   Scarves       0.38      0.33      0.35         9
#             Messenger Bag       0.00      0.00      0.00         7
#                   Compact       0.50      0.14      0.22         7
#               Night suits       1.00      0.06      0.12        16
#                  Leggings       0.50      0.14      0.21        22
#                 Eye Cream       0.00      0.00      0.00         2
#                 Lip Gloss       0.33      0.10      0.15        10
#                    Kurtis       0.00      0.00      0.00        24
#        Accessory Gift Set       1.00      0.67      0.80         6
#          Beauty Accessory       0.00      0.00      0.00         1
#                  Jumpsuit       0.00      0.00      0.00         5
#                Nightdress       0.69      0.27      0.39        33
#              Water Bottle       0.00      0.00      0.00         2
#                Kurta Sets       0.00      0.00      0.00         7
#         Face Moisturisers       0.00      0.00      0.00         3
#                Suspenders       1.00      0.80      0.89         5
#              Mobile Pouch       0.00      0.00      0.00         6
#                 Lip Liner       0.00      0.00      0.00         8
#                      Robe       0.00      0.00      0.00         0
#                 Stockings       0.00      0.00      0.00         3
#        Kajal and Eyeliner       1.00      0.08      0.15        12
#                 Eyeshadow       0.00      0.00      0.00         5
#                  Headband       0.00      0.00      0.00         1
#                   Patiala       0.00      0.00      0.00         3
#                 Camisoles       0.00      0.00      0.00         7
#                    Tights       0.00      0.00      0.00         1
#            Lounge Tshirts       0.00      0.00      0.00         0
#        Fragrance Gift Set       0.00      0.00      0.00         5
# Face Scrub and Exfoliator       0.00      0.00      0.00         1
#             Lounge Shorts       0.00      0.00      0.00         0
#                Baby Dolls       0.00      0.00      0.00         1
#     Foundation and Primer       0.33      0.08      0.13        12
#                Wristbands       0.00      0.00      0.00         0
#        Salwar and Dupatta       0.00      0.00      0.00         1
#                  Swimwear       0.00      0.00      0.00         0
#             Tablet Sleeve       0.00      0.00      0.00         0
#        Ties and Cufflinks       0.00      0.00      0.00         0
#                 Footballs       0.00      0.00      0.00         0
#                    Stoles       0.17      0.17      0.17        12
#                 Shapewear       0.00      0.00      0.00         2
#                    Salwar       0.00      0.00      0.00         2
#                 Cufflinks       0.22      0.82      0.35        11
#                 Concealer       0.00      0.00      0.00         2
#                   Rompers       0.00      0.00      0.00         3
#                  Jeggings       0.00      0.00      0.00         2
#                    Gloves       0.00      0.00      0.00         2
#                 Sunscreen       0.00      0.00      0.00         0
#                   Booties       0.00      0.00      0.00         2
#             Mask and Peel       0.00      0.00      0.00         4
#               Waist Pouch       0.00      0.00      0.00         1
#                 Rucksacks       0.00      0.00      0.00         1
#               Basketballs       0.00      0.00      0.00         1
#               Hair Colour       0.00      0.00      0.00         1
#                  Churidar       0.00      0.00      0.00         3
#              Clothing Set       0.00      0.00      0.00         0
#                   Mascara       0.00      0.00      0.00         1
#             Nehru Jackets       0.00      0.00      0.00         1
#            Cushion Covers       0.00      0.00      0.00         1
#                 Key chain       0.00      0.00      0.00         0
#                     Toner       0.00      0.00      0.00         1
#               Lip Plumper       0.00      0.00      0.00         2
#           Nail Essentials       0.00      0.00      0.00         2
#                 Umbrellas       0.00      0.00      0.00         0
#        Face Serum and Gel       0.00      0.00      0.00         1
#               Body Lotion       0.00      0.00      0.00         0
#            Makeup Remover       0.00      0.00      0.00         1
#             Rain Trousers       0.00      0.00      0.00         0
#                       Hat       0.00      0.00      0.00         0
#               Trolley Bag       0.00      0.00      0.00         0
#             Lehenga Choli       0.00      0.00      0.00         1
#                      Ipad       0.00      0.00      0.00         0
#
#                 micro avg       0.62      0.62      0.62      5000
#                 macro avg       0.24      0.21      0.20      5000
#              weighted avg       0.67      0.62      0.60      5000
#
# Accuracy for articleType: 0.6200
# Saved report to model_reports/classification_report_articleType.txt
#
# === Classification Report: baseColour ===
#
#                    precision    recall  f1-score   support
#
#             Black       0.66      0.88      0.76      1049
#              Grey       0.53      0.34      0.42       303
#             Green       0.54      0.73      0.62       251
#         Navy Blue       0.57      0.13      0.21       194
#              Blue       0.55      0.81      0.65       553
#             White       0.69      0.68      0.68       679
#             Beige       0.24      0.35      0.29        79
#            Bronze       0.00      0.00      0.00        12
#             Brown       0.70      0.52      0.59       417
#            Copper       0.00      0.00      0.00         5
#              Pink       0.55      0.43      0.48       213
#         Off White       0.00      0.00      0.00        19
#            Maroon       0.09      0.02      0.03        58
#            Purple       0.71      0.34      0.46       177
#             Khaki       0.00      0.00      0.00        17
#            Silver       0.48      0.43      0.45       138
#            Orange       0.70      0.23      0.35        69
#      Coffee Brown       0.00      0.00      0.00         4
#               Red       0.46      0.85      0.60       248
#          Charcoal       0.00      0.00      0.00        16
#              Gold       0.22      0.41      0.29        68
#             Steel       0.00      0.00      0.00        33
#             Multi       0.00      0.00      0.00        42
#           Magenta       0.00      0.00      0.00        23
#         Sea Green       0.00      0.00      0.00         2
#             Cream       0.00      0.00      0.00        40
#            Yellow       0.50      0.73      0.59        84
#             Olive       0.33      0.05      0.08        42
#      Grey Melange       0.00      0.00      0.00        15
#              Teal       0.00      0.00      0.00         5
#          Burgundy       0.00      0.00      0.00         5
#             Peach       1.00      0.04      0.08        25
#              Rust       0.00      0.00      0.00         6
#              Skin       0.17      0.04      0.06        25
#    Turquoise Blue       0.00      0.00      0.00        10
#               Tan       0.00      0.00      0.00        15
#          Lavender       0.00      0.00      0.00        28
#          Metallic       0.00      0.00      0.00         5
#           Mustard       0.00      0.00      0.00        11
#             Mauve       0.00      0.00      0.00         5
#              Nude       0.00      0.00      0.00         6
#              Rose       0.00      0.00      0.00         1
#    Mushroom Brown       0.00      0.00      0.00         1
#             Taupe       0.00      0.00      0.00         1
#        Lime Green       0.00      0.00      0.00         0
# Fluorescent Green       0.00      0.00      0.00         1
#
#         micro avg       0.58      0.58      0.58      5000
#         macro avg       0.21      0.17      0.17      5000
#      weighted avg       0.55      0.58      0.54      5000
#
# Accuracy for baseColour: 0.5826
# Saved report to model_reports/classification_report_baseColour.txt
#
# === Classification Report: usage ===
#
#               precision    recall  f1-score   support
#
#       Casual       0.86      0.97      0.91      3871
#       Ethnic       0.94      0.74      0.83       329
#       Sports       0.96      0.20      0.33       501
#       Formal       0.62      0.74      0.67       257
# Smart Casual       0.00      0.00      0.00         6
#        Party       0.00      0.00      0.00         3
#       Travel       0.00      0.00      0.00         1
#         Home       0.00      0.00      0.00         1
#
#    micro avg       0.85      0.86      0.86      4969
#    macro avg       0.42      0.33      0.34      4969
# weighted avg       0.86      0.86      0.83      4969
#
# Accuracy for usage: 0.8548
# Saved report to model_reports/classification_report_usage.txt
#
# Saved accuracy summary to model_reports/accuracy_summary.csv
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report

# 1) Ensure output folder exists
os.makedirs('model_reports', exist_ok=True)

# 2) Per-attribute reports and accuracies
accuracy_summary = {}
for i, attr in enumerate(attrs):
    y_true = y_te_int[i]
    y_pred_cls = np.argmax(y_pred[i], axis=1)
    
    # a) Text report
    report_text = classification_report(
        y_true,
        y_pred_cls,
        labels=list(range(num_classes[attr])),
        target_names=label_encoders[attr]
    )
    acc = accuracy_score(y_true, y_pred_cls)
    accuracy_summary[attr] = acc
    
    # b) Print to console
    print(f"\n--- {attr} ---")
    print(report_text)
    print(f"Accuracy ({attr}): {acc:.4f}")
    
    # c) Save to file
    txt_path = f'model_reports/classification_report_{attr}.txt'
    with open(txt_path, 'w') as f:
        f.write(f"=== Classification Report: {attr} ===\n\n")
        f.write(report_text)
        f.write(f"\nAccuracy: {acc:.4f}\n")
    print(f"Saved report for '{attr}' to {txt_path}")

# 3) Mean accuracy across all attributes
mean_acc = np.mean(list(accuracy_summary.values()))
print(f"\nMean tag accuracy: {mean_acc:.4f}")

# Save summary of per-attribute accuracies
df_acc = pd.DataFrame.from_dict(accuracy_summary, orient='index', columns=['accuracy'])
df_acc.index.name = 'attribute'
summary_path = 'model_reports/accuracy_summary.csv'
df_acc.to_csv(summary_path)
print(f"Saved accuracy summary to {summary_path}")

# 4) Flattened overall accuracy
y_true_flat = np.concatenate([y_te_int[i] for i in range(len(attrs))])
y_pred_flat = np.concatenate([np.argmax(y_pred[i], axis=1) for i in range(len(attrs))])
overall_flat_acc = accuracy_score(y_true_flat, y_pred_flat)
print(f"Overall (flattened) accuracy: {overall_flat_acc:.4f}")

# 5) Combined classification report (flattened)
# Build global label names
global_labels = []
for attr in attrs:
    global_labels += [f"{attr}_{cls}" for cls in label_encoders[attr]]

combined_report = classification_report(
    y_true_flat,
    y_pred_flat,
    labels=list(range(len(global_labels))),
    target_names=global_labels
)

print("\n=== Combined Classification Report (Flattened) ===")
print(combined_report)

# Save combined report to file
combined_path = 'model_reports/combined_classification_report.txt'
with open(combined_path, 'w') as f:
    f.write("=== Combined Classification Report (Flattened) ===\n\n")
    f.write(combined_report)
    f.write(f"\nOverall (flattened) accuracy: {overall_flat_acc:.4f}\n")
print(f"Saved combined report to {combined_path}")
# Out:
# --- gender ---
#               precision    recall  f1-score   support
#
#          Men       0.81      0.95      0.88      2492
#        Women       0.89      0.82      0.85      2122
#         Boys       0.00      0.00      0.00        85
#        Girls       0.25      0.03      0.05        65
#       Unisex       0.64      0.36      0.46       236
#
#     accuracy                           0.84      5000
#    macro avg       0.52      0.43      0.45      5000
# weighted avg       0.82      0.84      0.82      5000
#
# Accuracy (gender): 0.8374
# Saved report for 'gender' to model_reports/classification_report_gender.txt
#
# --- masterCategory ---
#                 precision    recall  f1-score   support
#
#        Apparel       0.99      0.93      0.96      2436
#    Accessories       0.81      0.99      0.89      1233
#       Footwear       1.00      0.97      0.98      1069
#  Personal Care       0.95      0.72      0.82       246
#     Free Items       0.00      0.00      0.00        14
# Sporting Goods       0.00      0.00      0.00         1
#           Home       0.00      0.00      0.00         1
#
#       accuracy                           0.94      5000
#      macro avg       0.54      0.51      0.52      5000
#   weighted avg       0.94      0.94      0.94      5000
#
# Accuracy (masterCategory): 0.9366
# Saved report for 'masterCategory' to model_reports/classification_report_masterCategory.txt
#
# --- subCategory ---
#                           precision    recall  f1-score   support
#
#               Bottomwear       0.88      0.89      0.88       297
#                  Topwear       0.97      0.93      0.95      1750
#                    Socks       0.89      0.88      0.88        73
#                  Watches       0.97      0.82      0.88       282
#                    Shoes       0.92      0.98      0.95       852
#                    Belts       1.00      0.64      0.78        75
#               Flip Flops       0.88      0.55      0.68       105
#                     Bags       0.85      0.85      0.85       339
#                Innerwear       0.89      0.81      0.85       221
#         Shoe Accessories       0.00      0.00      0.00         1
#                Jewellery       0.53      0.95      0.68       133
#                     Lips       0.89      0.50      0.64        48
#                    Saree       0.63      0.98      0.77        45
#                Fragrance       0.68      0.77      0.72        97
#                   Sandal       0.69      0.52      0.59       112
#                    Nails       0.49      0.57      0.53        35
#                    Dress       0.52      0.27      0.36        55
#                  Wallets       0.30      0.97      0.46       105
#                  Eyewear       1.00      0.51      0.67       112
#                 Headwear       0.65      0.50      0.57        34
# Loungewear and Nightwear       0.82      0.24      0.37        59
#                Skin Care       0.00      0.00      0.00        10
#               Free Gifts       0.11      0.07      0.09        14
#                 Mufflers       0.00      0.00      0.00         3
#                     Ties       0.79      1.00      0.88        30
#                   Makeup       0.80      0.09      0.16        44
#              Accessories       1.00      0.38      0.56        13
#                  Scarves       0.80      0.44      0.57         9
#       Beauty Accessories       0.00      0.00      0.00         1
#             Water Bottle       0.00      0.00      0.00         1
#              Apparel Set       0.00      0.00      0.00         7
#                     Skin       0.00      0.00      0.00         6
#                     Eyes       0.00      0.00      0.00         2
#       Sports Accessories       0.00      0.00      0.00         0
#                Cufflinks       0.26      0.82      0.39        11
#         Sports Equipment       0.00      0.00      0.00         1
#                   Stoles       0.33      0.08      0.13        12
#                   Gloves       0.00      0.00      0.00         2
#                     Hair       0.00      0.00      0.00         1
#                 Perfumes       0.00      0.00      0.00         0
#          Home Furnishing       0.00      0.00      0.00         1
#            Bath and Body       0.00      0.00      0.00         2
#                Umbrellas       0.00      0.00      0.00         0
#               Wristbands       0.00      0.00      0.00         0
#                 Vouchers       0.00      0.00      0.00         0
#
#                micro avg       0.84      0.84      0.84      5000
#                macro avg       0.43      0.38      0.37      5000
#             weighted avg       0.87      0.84      0.84      5000
#
# Accuracy (subCategory): 0.8422
# Saved report for 'subCategory' to model_reports/classification_report_subCategory.txt
#
# --- articleType ---
#                            precision    recall  f1-score   support
#
#               Track Pants       0.42      0.86      0.56        29
#                   Tshirts       0.94      0.53      0.68       831
#                    Shirts       0.47      0.95      0.63       364
#                     Socks       0.93      0.87      0.90        71
#                   Watches       0.96      0.85      0.90       282
#              Casual Shoes       0.55      0.81      0.65       313
#                     Belts       1.00      0.74      0.85        74
#                Flip Flops       0.88      0.55      0.67       106
#                  Handbags       0.91      0.82      0.86       189
#                      Tops       0.46      0.59      0.52       203
#                       Bra       0.77      0.92      0.84        60
#          Shoe Accessories       0.00      0.00      0.00         1
#               Sweatshirts       0.00      0.00      0.00        32
#              Formal Shoes       0.50      0.96      0.66        72
#                  Bracelet       0.09      0.56      0.16         9
#                  Lipstick       0.88      0.25      0.39        28
#                     Flats       0.00      0.00      0.00        61
#                    Kurtas       0.86      0.88      0.87       188
#                 Waistcoat       0.00      0.00      0.00         0
#              Sports Shoes       0.96      0.38      0.55       248
#                    Shorts       0.76      0.54      0.63        71
#                    Briefs       0.94      0.78      0.85       101
#                    Sarees       0.56      1.00      0.72        45
#     Perfume and Body Mist       0.38      0.84      0.53        61
#                     Heels       0.71      0.77      0.74       157
#                   Sandals       0.64      0.68      0.66       106
#                   Pendant       0.20      0.04      0.06        26
#               Nail Polish       0.35      0.57      0.43        35
#                Laptop Bag       0.00      0.00      0.00         7
#               Rain Jacket       0.00      0.00      0.00         2
#                   Dresses       0.55      0.42      0.48        50
#                    Skirts       0.50      0.16      0.24        19
#                   Wallets       0.25      0.99      0.40       105
#                   Blazers       0.00      0.00      0.00         1
#                      Ring       0.05      0.06      0.05        17
#                Sunglasses       1.00      0.55      0.71       112
#                  Clutches       0.00      0.00      0.00        37
#                     Shrug       0.00      0.00      0.00         0
#                      Caps       0.57      0.39      0.46        33
#           Innerwear Vests       0.74      0.52      0.61        33
#                  Earrings       0.44      0.87      0.58        45
#                  Trousers       0.62      0.60      0.61        50
#                    Boxers       1.00      0.67      0.80         3
#                 Backpacks       0.70      0.99      0.82        83
#                     Jeans       0.60      0.85      0.71        75
#             Jewellery Set       0.00      0.00      0.00         8
#                   Dupatta       0.00      0.00      0.00        13
#                    Capris       0.00      0.00      0.00        13
#                 Bath Robe       0.00      0.00      0.00         2
#                    Tunics       0.00      0.00      0.00        24
#                   Jackets       0.00      0.00      0.00        28
#              Lounge Pants       0.00      0.00      0.00         7
#    Face Wash and Cleanser       0.00      0.00      0.00         4
#       Necklace and Chains       0.78      0.30      0.44        23
#                Duffel Bag       0.00      0.00      0.00        11
#            Sports Sandals       0.00      0.00      0.00         6
#                 Deodorant       0.00      0.00      0.00        31
#                  Sweaters       0.33      0.10      0.15        31
#                Free Gifts       0.00      0.00      0.00        13
#                Tracksuits       0.00      0.00      0.00         3
#                Shoe Laces       0.00      0.00      0.00         0
#                     Trunk       0.64      0.60      0.62        15
#                  Mufflers       0.00      0.00      0.00         3
#                    Bangle       0.00      0.00      0.00         5
#                      Ties       0.82      1.00      0.90        31
#     Highlighter and Blush       0.00      0.00      0.00         6
#          Travel Accessory       0.00      0.00      0.00         3
#                  Lip Care       0.00      0.00      0.00         0
#                   Scarves       0.38      0.33      0.35         9
#             Messenger Bag       0.00      0.00      0.00         7
#                   Compact       0.50      0.14      0.22         7
#               Night suits       1.00      0.06      0.12        16
#                  Leggings       0.50      0.14      0.21        22
#                 Eye Cream       0.00      0.00      0.00         2
#                 Lip Gloss       0.33      0.10      0.15        10
#                    Kurtis       0.00      0.00      0.00        24
#        Accessory Gift Set       1.00      0.67      0.80         6
#          Beauty Accessory       0.00      0.00      0.00         1
#                  Jumpsuit       0.00      0.00      0.00         5
#                Nightdress       0.69      0.27      0.39        33
#              Water Bottle       0.00      0.00      0.00         2
#                Kurta Sets       0.00      0.00      0.00         7
#         Face Moisturisers       0.00      0.00      0.00         3
#                Suspenders       1.00      0.80      0.89         5
#              Mobile Pouch       0.00      0.00      0.00         6
#                 Lip Liner       0.00      0.00      0.00         8
#                      Robe       0.00      0.00      0.00         0
#                 Stockings       0.00      0.00      0.00         3
#        Kajal and Eyeliner       1.00      0.08      0.15        12
#                 Eyeshadow       0.00      0.00      0.00         5
#                  Headband       0.00      0.00      0.00         1
#                   Patiala       0.00      0.00      0.00         3
#                 Camisoles       0.00      0.00      0.00         7
#                    Tights       0.00      0.00      0.00         1
#            Lounge Tshirts       0.00      0.00      0.00         0
#        Fragrance Gift Set       0.00      0.00      0.00         5
# Face Scrub and Exfoliator       0.00      0.00      0.00         1
#             Lounge Shorts       0.00      0.00      0.00         0
#                Baby Dolls       0.00      0.00      0.00         1
#     Foundation and Primer       0.33      0.08      0.13        12
#                Wristbands       0.00      0.00      0.00         0
#        Salwar and Dupatta       0.00      0.00      0.00         1
#                  Swimwear       0.00      0.00      0.00         0
#             Tablet Sleeve       0.00      0.00      0.00         0
#        Ties and Cufflinks       0.00      0.00      0.00         0
#                 Footballs       0.00      0.00      0.00         0
#                    Stoles       0.17      0.17      0.17        12
#                 Shapewear       0.00      0.00      0.00         2
#                    Salwar       0.00      0.00      0.00         2
#                 Cufflinks       0.22      0.82      0.35        11
#                 Concealer       0.00      0.00      0.00         2
#                   Rompers       0.00      0.00      0.00         3
#                  Jeggings       0.00      0.00      0.00         2
#                    Gloves       0.00      0.00      0.00         2
#                 Sunscreen       0.00      0.00      0.00         0
#                   Booties       0.00      0.00      0.00         2
#             Mask and Peel       0.00      0.00      0.00         4
#               Waist Pouch       0.00      0.00      0.00         1
#                 Rucksacks       0.00      0.00      0.00         1
#               Basketballs       0.00      0.00      0.00         1
#               Hair Colour       0.00      0.00      0.00         1
#                  Churidar       0.00      0.00      0.00         3
#              Clothing Set       0.00      0.00      0.00         0
#                   Mascara       0.00      0.00      0.00         1
#             Nehru Jackets       0.00      0.00      0.00         1
#            Cushion Covers       0.00      0.00      0.00         1
#                 Key chain       0.00      0.00      0.00         0
#                     Toner       0.00      0.00      0.00         1
#               Lip Plumper       0.00      0.00      0.00         2
#           Nail Essentials       0.00      0.00      0.00         2
#                 Umbrellas       0.00      0.00      0.00         0
#        Face Serum and Gel       0.00      0.00      0.00         1
#               Body Lotion       0.00      0.00      0.00         0
#            Makeup Remover       0.00      0.00      0.00         1
#             Rain Trousers       0.00      0.00      0.00         0
#                       Hat       0.00      0.00      0.00         0
#               Trolley Bag       0.00      0.00      0.00         0
#             Lehenga Choli       0.00      0.00      0.00         1
#                      Ipad       0.00      0.00      0.00         0
#
#                 micro avg       0.62      0.62      0.62      5000
#                 macro avg       0.24      0.21      0.20      5000
#              weighted avg       0.67      0.62      0.60      5000
#
# Accuracy (articleType): 0.6200
# Saved report for 'articleType' to model_reports/classification_report_articleType.txt
#
# --- baseColour ---
#                    precision    recall  f1-score   support
#
#             Black       0.66      0.88      0.76      1049
#              Grey       0.53      0.34      0.42       303
#             Green       0.54      0.73      0.62       251
#         Navy Blue       0.57      0.13      0.21       194
#              Blue       0.55      0.81      0.65       553
#             White       0.69      0.68      0.68       679
#             Beige       0.24      0.35      0.29        79
#            Bronze       0.00      0.00      0.00        12
#             Brown       0.70      0.52      0.59       417
#            Copper       0.00      0.00      0.00         5
#              Pink       0.55      0.43      0.48       213
#         Off White       0.00      0.00      0.00        19
#            Maroon       0.09      0.02      0.03        58
#            Purple       0.71      0.34      0.46       177
#             Khaki       0.00      0.00      0.00        17
#            Silver       0.48      0.43      0.45       138
#            Orange       0.70      0.23      0.35        69
#      Coffee Brown       0.00      0.00      0.00         4
#               Red       0.46      0.85      0.60       248
#          Charcoal       0.00      0.00      0.00        16
#              Gold       0.22      0.41      0.29        68
#             Steel       0.00      0.00      0.00        33
#             Multi       0.00      0.00      0.00        42
#           Magenta       0.00      0.00      0.00        23
#         Sea Green       0.00      0.00      0.00         2
#             Cream       0.00      0.00      0.00        40
#            Yellow       0.50      0.73      0.59        84
#             Olive       0.33      0.05      0.08        42
#      Grey Melange       0.00      0.00      0.00        15
#              Teal       0.00      0.00      0.00         5
#          Burgundy       0.00      0.00      0.00         5
#             Peach       1.00      0.04      0.08        25
#              Rust       0.00      0.00      0.00         6
#              Skin       0.17      0.04      0.06        25
#    Turquoise Blue       0.00      0.00      0.00        10
#               Tan       0.00      0.00      0.00        15
#          Lavender       0.00      0.00      0.00        28
#          Metallic       0.00      0.00      0.00         5
#           Mustard       0.00      0.00      0.00        11
#             Mauve       0.00      0.00      0.00         5
#              Nude       0.00      0.00      0.00         6
#              Rose       0.00      0.00      0.00         1
#    Mushroom Brown       0.00      0.00      0.00         1
#             Taupe       0.00      0.00      0.00         1
#        Lime Green       0.00      0.00      0.00         0
# Fluorescent Green       0.00      0.00      0.00         1
#
#         micro avg       0.58      0.58      0.58      5000
#         macro avg       0.21      0.17      0.17      5000
#      weighted avg       0.55      0.58      0.54      5000
#
# Accuracy (baseColour): 0.5826
# Saved report for 'baseColour' to model_reports/classification_report_baseColour.txt
#
# --- usage ---
#               precision    recall  f1-score   support
#
#       Casual       0.86      0.97      0.91      3871
#       Ethnic       0.94      0.74      0.83       329
#       Sports       0.96      0.20      0.33       501
#       Formal       0.62      0.74      0.67       257
# Smart Casual       0.00      0.00      0.00         6
#        Party       0.00      0.00      0.00         3
#       Travel       0.00      0.00      0.00         1
#         Home       0.00      0.00      0.00         1
#
#    micro avg       0.85      0.86      0.86      4969
#    macro avg       0.42      0.33      0.34      4969
# weighted avg       0.86      0.86      0.83      4969
#
# Accuracy (usage): 0.8548
# Saved report for 'usage' to model_reports/classification_report_usage.txt
#
# Mean tag accuracy: 0.7789
# Saved accuracy summary to model_reports/accuracy_summary.csv
# Overall (flattened) accuracy: 0.7789
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# === Combined Classification Report (Flattened) ===
#                                        precision    recall  f1-score   support
#
#                            gender_Men       0.85      0.94      0.89     10174
#                          gender_Women       0.89      0.82      0.85      6568
#                           gender_Boys       0.76      0.74      0.75      2343
#                          gender_Girls       0.81      0.62      0.70      1115
#                         gender_Unisex       0.76      0.83      0.79      1943
#                masterCategory_Apparel       0.64      0.71      0.67      1071
#            masterCategory_Accessories       0.60      0.54      0.57       260
#               masterCategory_Footwear       0.85      0.76      0.80       458
#          masterCategory_Personal Care       0.81      0.67      0.73       827
#             masterCategory_Free Items       0.46      0.57      0.51       209
#         masterCategory_Sporting Goods       0.58      0.67      0.62       406
#                   masterCategory_Home       0.89      0.35      0.51        68
#                subCategory_Bottomwear       0.52      0.33      0.41       135
#                   subCategory_Topwear       0.61      0.59      0.60       346
#                     subCategory_Socks       0.46      0.46      0.46       138
#                   subCategory_Watches       0.50      0.43      0.46       201
#                     subCategory_Shoes       0.60      0.17      0.26       185
#                     subCategory_Belts       0.50      0.90      0.65       297
#                subCategory_Flip Flops       0.52      0.74      0.61       360
#                      subCategory_Bags       0.90      0.38      0.53       298
#                 subCategory_Innerwear       0.42      0.40      0.41       198
#          subCategory_Shoe Accessories       0.94      0.55      0.69       144
#                 subCategory_Jewellery       0.52      0.46      0.48       101
#                      subCategory_Lips       0.38      0.59      0.46        87
#                     subCategory_Saree       0.73      0.80      0.76       189
#                 subCategory_Fragrance       0.64      0.40      0.49       190
#                    subCategory_Sandal       0.51      0.54      0.53       123
#                     subCategory_Nails       0.38      0.30      0.34        86
#                     subCategory_Dress       0.00      0.00      0.00        23
#                   subCategory_Wallets       0.00      0.00      0.00         8
#                   subCategory_Eyewear       0.55      0.34      0.42        62
#                  subCategory_Headwear       0.50      0.08      0.14        50
#  subCategory_Loungewear and Nightwear       0.25      0.92      0.39       113
#                 subCategory_Skin Care       0.17      0.04      0.06        26
#                subCategory_Free Gifts       0.18      0.26      0.22        38
#                  subCategory_Mufflers       1.00      0.48      0.65       128
#                      subCategory_Ties       0.08      0.01      0.02        77
#                    subCategory_Makeup       0.00      0.00      0.00         7
#               subCategory_Accessories       0.54      0.29      0.38        45
#                   subCategory_Scarves       0.74      0.45      0.56        38
#        subCategory_Beauty Accessories       0.44      0.75      0.55        52
#              subCategory_Water Bottle       0.62      0.57      0.59        53
#               subCategory_Apparel Set       1.00      0.50      0.67         4
#                      subCategory_Skin       0.70      0.98      0.82        84
#                      subCategory_Eyes       0.60      0.85      0.71        75
#        subCategory_Sports Accessories       0.00      0.00      0.00         9
#                 subCategory_Cufflinks       0.00      0.00      0.00        13
#          subCategory_Sports Equipment       0.00      0.00      0.00        13
#                    subCategory_Stoles       0.00      0.00      0.00         2
#                    subCategory_Gloves       0.00      0.00      0.00        24
#                      subCategory_Hair       0.00      0.00      0.00        28
#                  subCategory_Perfumes       0.00      0.00      0.00         7
#           subCategory_Home Furnishing       0.00      0.00      0.00         4
#             subCategory_Bath and Body       0.78      0.30      0.44        23
#                 subCategory_Umbrellas       0.00      0.00      0.00        11
#                subCategory_Wristbands       0.00      0.00      0.00         6
#                  subCategory_Vouchers       0.00      0.00      0.00        31
#               articleType_Track Pants       0.33      0.10      0.15        31
#                   articleType_Tshirts       0.00      0.00      0.00        13
#                    articleType_Shirts       0.00      0.00      0.00         3
#                     articleType_Socks       0.00      0.00      0.00         0
#                   articleType_Watches       0.64      0.60      0.62        15
#              articleType_Casual Shoes       0.00      0.00      0.00         3
#                     articleType_Belts       0.00      0.00      0.00         5
#                articleType_Flip Flops       0.82      1.00      0.90        31
#                  articleType_Handbags       0.00      0.00      0.00         6
#                      articleType_Tops       0.00      0.00      0.00         3
#                       articleType_Bra       0.00      0.00      0.00         0
#          articleType_Shoe Accessories       0.38      0.33      0.35         9
#               articleType_Sweatshirts       0.00      0.00      0.00         7
#              articleType_Formal Shoes       0.50      0.14      0.22         7
#                  articleType_Bracelet       1.00      0.06      0.12        16
#                  articleType_Lipstick       0.50      0.14      0.21        22
#                     articleType_Flats       0.00      0.00      0.00         2
#                    articleType_Kurtas       0.33      0.10      0.15        10
#                 articleType_Waistcoat       0.00      0.00      0.00        24
#              articleType_Sports Shoes       1.00      0.67      0.80         6
#                    articleType_Shorts       0.00      0.00      0.00         1
#                    articleType_Briefs       0.00      0.00      0.00         5
#                    articleType_Sarees       0.69      0.27      0.39        33
#     articleType_Perfume and Body Mist       0.00      0.00      0.00         2
#                     articleType_Heels       0.00      0.00      0.00         7
#                   articleType_Sandals       0.00      0.00      0.00         3
#                   articleType_Pendant       1.00      0.80      0.89         5
#               articleType_Nail Polish       0.00      0.00      0.00         6
#                articleType_Laptop Bag       0.00      0.00      0.00         8
#               articleType_Rain Jacket       0.00      0.00      0.00         0
#                   articleType_Dresses       0.00      0.00      0.00         3
#                    articleType_Skirts       1.00      0.08      0.15        12
#                   articleType_Wallets       0.00      0.00      0.00         5
#                   articleType_Blazers       0.00      0.00      0.00         1
#                      articleType_Ring       0.00      0.00      0.00         3
#                articleType_Sunglasses       0.00      0.00      0.00         7
#                  articleType_Clutches       0.00      0.00      0.00         1
#                     articleType_Shrug       0.00      0.00      0.00         0
#                      articleType_Caps       0.00      0.00      0.00         5
#           articleType_Innerwear Vests       0.00      0.00      0.00         1
#                  articleType_Earrings       0.00      0.00      0.00         0
#                  articleType_Trousers       0.00      0.00      0.00         1
#                    articleType_Boxers       0.33      0.08      0.13        12
#                 articleType_Backpacks       0.00      0.00      0.00         0
#                     articleType_Jeans       0.00      0.00      0.00         1
#             articleType_Jewellery Set       0.00      0.00      0.00         0
#                   articleType_Dupatta       0.00      0.00      0.00         0
#                    articleType_Capris       0.00      0.00      0.00         0
#                 articleType_Bath Robe       0.00      0.00      0.00         0
#                    articleType_Tunics       0.17      0.17      0.17        12
#                   articleType_Jackets       0.00      0.00      0.00         2
#              articleType_Lounge Pants       0.00      0.00      0.00         2
#    articleType_Face Wash and Cleanser       0.22      0.82      0.35        11
#       articleType_Necklace and Chains       0.00      0.00      0.00         2
#                articleType_Duffel Bag       0.00      0.00      0.00         3
#            articleType_Sports Sandals       0.00      0.00      0.00         2
#                 articleType_Deodorant       0.00      0.00      0.00         2
#                  articleType_Sweaters       0.00      0.00      0.00         0
#                articleType_Free Gifts       0.00      0.00      0.00         2
#                articleType_Tracksuits       0.00      0.00      0.00         4
#                articleType_Shoe Laces       0.00      0.00      0.00         1
#                     articleType_Trunk       0.00      0.00      0.00         1
#                  articleType_Mufflers       0.00      0.00      0.00         1
#                    articleType_Bangle       0.00      0.00      0.00         1
#                      articleType_Ties       0.00      0.00      0.00         3
#     articleType_Highlighter and Blush       0.00      0.00      0.00         0
#          articleType_Travel Accessory       0.00      0.00      0.00         1
#                  articleType_Lip Care       0.00      0.00      0.00         1
#                   articleType_Scarves       0.00      0.00      0.00         1
#             articleType_Messenger Bag       0.00      0.00      0.00         0
#                   articleType_Compact       0.00      0.00      0.00         1
#               articleType_Night suits       0.00      0.00      0.00         2
#                  articleType_Leggings       0.00      0.00      0.00         2
#                 articleType_Eye Cream       0.00      0.00      0.00         0
#                 articleType_Lip Gloss       0.00      0.00      0.00         1
#                    articleType_Kurtis       0.00      0.00      0.00         0
#        articleType_Accessory Gift Set       0.00      0.00      0.00         1
#          articleType_Beauty Accessory       0.00      0.00      0.00         0
#                  articleType_Jumpsuit       0.00      0.00      0.00         0
#                articleType_Nightdress       0.00      0.00      0.00         0
#              articleType_Water Bottle       0.00      0.00      0.00         1
#                articleType_Kurta Sets       0.00      0.00      0.00         0
#         articleType_Face Moisturisers       0.00      0.00      0.00         0
#                articleType_Suspenders       0.00      0.00      0.00         0
#              articleType_Mobile Pouch       0.00      0.00      0.00         0
#                 articleType_Lip Liner       0.00      0.00      0.00         0
#                      articleType_Robe       0.00      0.00      0.00         0
#                 articleType_Stockings       0.00      0.00      0.00         0
#        articleType_Kajal and Eyeliner       0.00      0.00      0.00         0
#                 articleType_Eyeshadow       0.00      0.00      0.00         0
#                  articleType_Headband       0.00      0.00      0.00         0
#                   articleType_Patiala       0.00      0.00      0.00         0
#                 articleType_Camisoles       0.00      0.00      0.00         0
#                    articleType_Tights       0.00      0.00      0.00         0
#            articleType_Lounge Tshirts       0.00      0.00      0.00         0
#        articleType_Fragrance Gift Set       0.00      0.00      0.00         0
# articleType_Face Scrub and Exfoliator       0.00      0.00      0.00         0
#             articleType_Lounge Shorts       0.00      0.00      0.00         0
#                articleType_Baby Dolls       0.00      0.00      0.00         0
#     articleType_Foundation and Primer       0.00      0.00      0.00         0
#                articleType_Wristbands       0.00      0.00      0.00         0
#        articleType_Salwar and Dupatta       0.00      0.00      0.00         0
#                  articleType_Swimwear       0.00      0.00      0.00         0
#             articleType_Tablet Sleeve       0.00      0.00      0.00         0
#        articleType_Ties and Cufflinks       0.00      0.00      0.00         0
#                 articleType_Footballs       0.00      0.00      0.00         0
#                    articleType_Stoles       0.00      0.00      0.00         0
#                 articleType_Shapewear       0.00      0.00      0.00         0
#                    articleType_Salwar       0.00      0.00      0.00         0
#                 articleType_Cufflinks       0.00      0.00      0.00         0
#                 articleType_Concealer       0.00      0.00      0.00         0
#                   articleType_Rompers       0.00      0.00      0.00         0
#                  articleType_Jeggings       0.00      0.00      0.00         0
#                    articleType_Gloves       0.00      0.00      0.00         0
#                 articleType_Sunscreen       0.00      0.00      0.00         0
#                   articleType_Booties       0.00      0.00      0.00         0
#             articleType_Mask and Peel       0.00      0.00      0.00         0
#               articleType_Waist Pouch       0.00      0.00      0.00         0
#                 articleType_Rucksacks       0.00      0.00      0.00         0
#               articleType_Basketballs       0.00      0.00      0.00         0
#               articleType_Hair Colour       0.00      0.00      0.00         0
#                  articleType_Churidar       0.00      0.00      0.00         0
#              articleType_Clothing Set       0.00      0.00      0.00         0
#                   articleType_Mascara       0.00      0.00      0.00         0
#             articleType_Nehru Jackets       0.00      0.00      0.00         0
#            articleType_Cushion Covers       0.00      0.00      0.00         0
#                 articleType_Key chain       0.00      0.00      0.00         0
#                     articleType_Toner       0.00      0.00      0.00         0
#               articleType_Lip Plumper       0.00      0.00      0.00         0
#           articleType_Nail Essentials       0.00      0.00      0.00         0
#                 articleType_Umbrellas       0.00      0.00      0.00         0
#        articleType_Face Serum and Gel       0.00      0.00      0.00         0
#               articleType_Body Lotion       0.00      0.00      0.00         0
#            articleType_Makeup Remover       0.00      0.00      0.00         0
#             articleType_Rain Trousers       0.00      0.00      0.00         0
#                       articleType_Hat       0.00      0.00      0.00         0
#               articleType_Trolley Bag       0.00      0.00      0.00         0
#             articleType_Lehenga Choli       0.00      0.00      0.00         0
#                      articleType_Ipad       0.00      0.00      0.00         0
#                      baseColour_Black       0.00      0.00      0.00         0
#                       baseColour_Grey       0.00      0.00      0.00         0
#                      baseColour_Green       0.00      0.00      0.00         0
#                  baseColour_Navy Blue       0.00      0.00      0.00         0
#                       baseColour_Blue       0.00      0.00      0.00         0
#                      baseColour_White       0.00      0.00      0.00         0
#                      baseColour_Beige       0.00      0.00      0.00         0
#                     baseColour_Bronze       0.00      0.00      0.00         0
#                      baseColour_Brown       0.00      0.00      0.00         0
#                     baseColour_Copper       0.00      0.00      0.00         0
#                       baseColour_Pink       0.00      0.00      0.00         0
#                  baseColour_Off White       0.00      0.00      0.00         0
#                     baseColour_Maroon       0.00      0.00      0.00         0
#                     baseColour_Purple       0.00      0.00      0.00         0
#                      baseColour_Khaki       0.00      0.00      0.00         0
#                     baseColour_Silver       0.00      0.00      0.00         0
#                     baseColour_Orange       0.00      0.00      0.00         0
#               baseColour_Coffee Brown       0.00      0.00      0.00         0
#                        baseColour_Red       0.00      0.00      0.00         0
#                   baseColour_Charcoal       0.00      0.00      0.00         0
#                       baseColour_Gold       0.00      0.00      0.00         0
#                      baseColour_Steel       0.00      0.00      0.00         0
#                      baseColour_Multi       0.00      0.00      0.00         0
#                    baseColour_Magenta       0.00      0.00      0.00         0
#                  baseColour_Sea Green       0.00      0.00      0.00         0
#                      baseColour_Cream       0.00      0.00      0.00         0
#                     baseColour_Yellow       0.00      0.00      0.00         0
#                      baseColour_Olive       0.00      0.00      0.00         0
#               baseColour_Grey Melange       0.00      0.00      0.00         0
#                       baseColour_Teal       0.00      0.00      0.00         0
#                   baseColour_Burgundy       0.00      0.00      0.00         0
#                      baseColour_Peach       0.00      0.00      0.00         0
#                       baseColour_Rust       0.00      0.00      0.00         0
#                       baseColour_Skin       0.00      0.00      0.00         0
#             baseColour_Turquoise Blue       0.00      0.00      0.00         0
#                        baseColour_Tan       0.00      0.00      0.00         0
#                   baseColour_Lavender       0.00      0.00      0.00         0
#                   baseColour_Metallic       0.00      0.00      0.00         0
#                    baseColour_Mustard       0.00      0.00      0.00         0
#                      baseColour_Mauve       0.00      0.00      0.00         0
#                       baseColour_Nude       0.00      0.00      0.00         0
#                       baseColour_Rose       0.00      0.00      0.00         0
#             baseColour_Mushroom Brown       0.00      0.00      0.00         0
#                      baseColour_Taupe       0.00      0.00      0.00         0
#                 baseColour_Lime Green       0.00      0.00      0.00         0
#          baseColour_Fluorescent Green       0.00      0.00      0.00         0
#                          usage_Casual       0.00      0.00      0.00         0
#                          usage_Ethnic       0.00      0.00      0.00         0
#                          usage_Sports       0.00      0.00      0.00         0
#                          usage_Formal       0.00      0.00      0.00         0
#                    usage_Smart Casual       0.00      0.00      0.00         0
#                           usage_Party       0.00      0.00      0.00         0
#                          usage_Travel       0.00      0.00      0.00         0
#                            usage_Home       0.00      0.00      0.00         0
#
#                             micro avg       0.78      0.78      0.78     29969
#                             macro avg       0.14      0.11      0.12     29969
#                          weighted avg       0.78      0.78      0.77     29969
#
# Saved combined report to model_reports/combined_classification_report.txt
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# 1) Compute overall MSE & RMSE
Yt = np.concatenate([y_te[i] for i in range(len(attrs))], axis=1)
Yp = np.concatenate([y_pred[i] for i in range(len(attrs))], axis=1)
mse = mean_squared_error(Yt, Yp)
rmse = np.sqrt(mse)
print(f"Overall MSE: {mse:.4f}, RMSE: {rmse:.4f}")

# 2) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 3) Plot MSE & RMSE as a bar chart
fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(['MSE', 'RMSE'], [mse, rmse])
ax.set_title('Overall MSE & RMSE')
ax.set_ylabel('Value')
for i, v in enumerate([mse, rmse]):
    ax.text(i, v + (v * 0.02), f"{v:.2f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()

# 4) Save the figure
output_path = 'model_plots/mse_rmse_overall.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"Plot saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Overall MSE: 0.0074, RMSE: 0.0859
# Plot saved to model_plots/mse_rmse_overall.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# 1) Select history for batch size 32
hist = histories[32].history  # replace 32 with whichever batch size you want

# 2) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 3) Create the figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(8, 8))

# (a) Total Loss plot
axes[0].plot(hist['loss'], label='train total loss')
axes[0].plot(hist['val_loss'], label='val total loss')
axes[0].set_title('Total Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend(loc='upper right')

# (b) Mean Accuracy Across Tags
avg_train_acc = [
    np.mean([hist[f'{a}_accuracy'][i] for a in attrs])
    for i in range(len(hist['loss']))
]
avg_val_acc = [
    np.mean([hist[f'val_{a}_accuracy'][i] for a in attrs])
    for i in range(len(hist['loss']))
]
axes[1].plot(avg_train_acc, label='train mean acc', marker='o')
axes[1].plot(avg_val_acc,   label='val mean acc', marker='o')
axes[1].set_title('Mean Accuracy Across Tags')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend(loc='lower right')

plt.tight_layout()

# 4) Save the figure
output_path = 'model_plots/loss_and_mean_accuracy_bs32.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"Plot saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Plot saved to model_plots/loss_and_mean_accuracy_bs32.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score
from tensorflow.keras.utils import to_categorical

# 1) Build big arrays of shape (N_total, )
y_true_list = []
y_score_list = []

for i, attr in enumerate(attrs):
    # one-hot true labels and predicted scores
    y_true = to_categorical(y_te_int[i], num_classes[attr])  # shape (n_samples, n_classes)
    y_score = y_pred[i]                                        # shape (n_samples, n_classes)
    
    # append flattened
    y_true_list.append(y_true.ravel())
    y_score_list.append(y_score.ravel())

# concatenate across attributes
y_true_all = np.concatenate(y_true_list)
y_score_all = np.concatenate(y_score_list)

# 2) Compute overall PR curve
prec, rec, _ = precision_recall_curve(y_true_all, y_score_all)
ap_micro = average_precision_score(y_true_all, y_score_all, average='micro')

# 3) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 4) Plot
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(rec, prec, label=f'Micro-averaged PR (AP = {ap_micro:.2f})', marker='.')
ax.set_xlabel('Recall')
ax.set_ylabel('Precision')
ax.set_title('Overall (Micro-averaged) Precision–Recall Curve')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.legend(loc='lower left')
plt.tight_layout()

# 5) Save the figure
output_path = 'model_plots/precision_recall_curve_micro_avg.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"Precision-Recall curve saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Precision-Recall curve saved to model_plots/precision_recall_curve_micro_avg.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score
from tensorflow.keras.utils import to_categorical

# 1) Concatenate all one-hot true labels and predicted scores
y_true_all = np.concatenate([
    to_categorical(y_te_int[i], num_classes[attr])
    for i, attr in enumerate(attrs)
], axis=1)

y_score_all = np.concatenate([
    y_pred[i]
    for i in range(len(attrs))
], axis=1)

# 2) Compute micro-average precision–recall
prec, rec, _ = precision_recall_curve(y_true_all.ravel(), y_score_all.ravel())
ap_micro = average_precision_score(y_true_all, y_score_all, average='micro')

# 3) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 4) Plot
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(rec, prec, lw=2, label=f'Micro-avg PR (AP={ap_micro:.2f})')
ax.set_xlabel('Recall')
ax.set_ylabel('Precision')
ax.set_title('Overall Precision–Recall Curve (Micro-Average)')
ax.legend(loc='upper right', borderaxespad=0)
ax.grid(alpha=0.3)
plt.tight_layout()

# 5) Save the figure
output_path = 'model_plots/precision_recall_curve_micro_avg.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"Precision–Recall curve saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Precision–Recall curve saved to model_plots/precision_recall_curve_micro_avg.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.utils import to_categorical

# 1) Choose attribute index (e.g., first attribute)
i = 0
attr = attrs[i]

# 2) Prepare true labels and predicted scores
y_true = to_categorical(y_te_int[i], num_classes[attr])  # shape (n_samples, n_classes)
y_score = y_pred[i]                                       # shape (n_samples, n_classes)

# 3) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 4) Plot ROC curves
fig, ax = plt.subplots(figsize=(6, 6))
for c in range(num_classes[attr]):
    fpr, tpr, _ = roc_curve(y_true[:, c], y_score[:, c])
    roc_auc = auc(fpr, tpr)
    ax.plot(fpr, tpr, label=f'{label_encoders[attr][c]} (AUC={roc_auc:.2f})')

# Diagonal line
ax.plot([0, 1], [0, 1], 'k--', linewidth=1)

# Labels and title
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title(f'ROC Curve for {attr}')
ax.legend(loc='lower right', fontsize='small')
ax.grid(alpha=0.3)

plt.tight_layout()

# 5) Save the figure
output_path = f'model_plots/roc_curve_{attr}.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"ROC curve saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# ROC curve saved to model_plots/roc_curve_gender.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# 1) Compute per-attribute macro-F1
macro_f1s = []
for i, attr in enumerate(attrs):
    y_true        = y_te_int[i]
    y_pred_labels = np.argmax(y_pred[i], axis=1)
    macro = f1_score(y_true, y_pred_labels, average='macro', zero_division=0)
    macro_f1s.append(macro)

# 2) Compute overall F1
overall_f1 = np.mean(macro_f1s)

# 3) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 4) Plot Overall F1
fig, ax = plt.subplots(figsize=(5, 5))
ax.bar(['Overall F1'], [overall_f1])
ax.set_ylim(0, 1)
ax.set_title('Overall Model F1 Score')
ax.set_ylabel('F1 Score')

# Annotate the bar
ax.text(0, overall_f1 + 0.02, f'{overall_f1:.2f}', ha='center', va='bottom', fontsize=12)

plt.tight_layout()

# 5) Save the figure
output_path = 'model_plots/overall_f1_score.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"Overall F1 score plot saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# Overall F1 score plot saved to model_plots/overall_f1_score.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from tensorflow.keras.models import Model

# 1) Extract penultimate‐layer output
penult_layer = best_model.layers[-2].output  # second‐to‐last layer
feat_extractor = Model(inputs=best_model.input, outputs=penult_layer)
embeddings = feat_extractor.predict(X_te)

# 2) Choose a safe perplexity
n_samples = embeddings.shape[0]
perplexity = max(5, min(30, (n_samples // 3) - 1))
print(f"Using perplexity={perplexity} (n_samples={n_samples})")

# 3) t-SNE to 2D
tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
proj = tsne.fit_transform(embeddings)

# 4) Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# 5) Plot, colored by first attribute (e.g., 'gender')
fig, ax = plt.subplots(figsize=(6, 6))
for label in np.unique(y_te_int[0]):
    mask = (y_te_int[0] == label)
    ax.scatter(
        proj[mask, 0],
        proj[mask, 1],
        label=label_encoders[attrs[0]][label],
        alpha=0.6
    )

ax.legend(loc='best', fontsize='small')
ax.set_xlabel('t-SNE Dim 1')
ax.set_ylabel('t-SNE Dim 2')
ax.set_title(f"t-SNE of Penultimate Features (perplexity={perplexity})")
plt.tight_layout()

# 6) Save the figure
output_path = 'model_plots/tsne_penultimate_features.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')
plt.close(fig)

print(f"t-SNE plot saved to {output_path}")
plt.tight_layout()
plt.show()
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 25s 155ms/step
# Using perplexity=30 (n_samples=5000)
# t-SNE plot saved to model_plots/tsne_penultimate_features.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix, precision_recall_curve, average_precision_score,
    roc_curve, auc, f1_score
)
from sklearn.manifold import TSNE
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model

# Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

sns.set(style="whitegrid")
palette = sns.color_palette("tab10", n_colors=len(attrs))
hist = histories[best_bs].history  # choose your best batch size
epochs_range = range(1, len(hist['loss']) + 1)

# ——— 1. Training & Validation Curves ———
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10))
# Loss
ax1.plot(epochs_range, hist['loss'], label='Train Loss', color='C0')
ax1.plot(epochs_range, hist['val_loss'], label='Val Loss',   color='C1')
ax1.set_title('Total Loss vs. Epoch', fontsize=14)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend(loc='upper right')
# Mean Accuracy
mean_train = [
    np.mean([hist[f'{a}_accuracy'][i] for a in attrs])
    for i in range(len(epochs_range))
]
mean_val = [
    np.mean([hist[f'val_{a}_accuracy'][i] for a in attrs])
    for i in range(len(epochs_range))
]
ax2.plot(epochs_range, mean_train, label='Train Mean Acc', color='C2')
ax2.plot(epochs_range, mean_val,   label='Val Mean Acc',   color='C3')
ax2.set_title('Mean Tag Accuracy vs. Epoch', fontsize=14)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend(loc='upper right')
plt.tight_layout()
fig.savefig('model_plots/training_validation_curves.png', dpi=300, bbox_inches='tight')
plt.close(fig)

# ——— 2. Normalized Confusion Matrices ———
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
for i, attr in enumerate(attrs):
    ax = axes.flat[i]
    cm = confusion_matrix(y_te_int[i], np.argmax(y_pred[i], axis=1))
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    sns.heatmap(
        cm_norm, annot=True, fmt='.2f', cmap='Blues',
        xticklabels=label_encoders[attr],
        yticklabels=label_encoders[attr],
        cbar=False, ax=ax
    )
    ax.set_title(f'{attr} Confusion Matrix (Normalized)', fontsize=12)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
plt.tight_layout()
fig.savefig('model_plots/normalized_confusion_matrices.png', dpi=300, bbox_inches='tight')
plt.close(fig)

# ——— 3. Precision–Recall Curves ———
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
for i, attr in enumerate(attrs):
    ax = axes.flat[i]
    y_true = to_categorical(y_te_int[i], num_classes[attr])
    y_score = y_pred[i]
    for c in range(num_classes[attr]):
        prec, rec, _ = precision_recall_curve(y_true[:, c], y_score[:, c])
        ap = average_precision_score(y_true[:, c], y_score[:, c])
        ax.plot(rec, prec,
                label=f'{label_encoders[attr][c]} (AP={ap:.2f})',
                color=palette[c % len(palette)])
    ax.set_title(f'{attr} Precision–Recall', fontsize=12)
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
plt.tight_layout()
fig.savefig('model_plots/precision_recall_curves.png', dpi=300, bbox_inches='tight')
plt.close(fig)

# ——— 4. ROC Curves & AUC ———
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
for i, attr in enumerate(attrs):
    ax = axes.flat[i]
    y_true = to_categorical(y_te_int[i], num_classes[attr])
    y_score = y_pred[i]
    for c in range(num_classes[attr]):
        fpr, tpr, _ = roc_curve(y_true[:, c], y_score[:, c])
        r_auc = auc(fpr, tpr)
        ax.plot(fpr, tpr,
                label=f'{label_encoders[attr][c]} (AUC={r_auc:.2f})',
                color=palette[c % len(palette)])
    ax.plot([0, 1], [0, 1], 'k--', linewidth=1)
    ax.set_title(f'{attr} ROC Curve', fontsize=12)
    ax.set_xlabel('FPR')
    ax.set_ylabel('TPR')
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
plt.tight_layout()
fig.savefig('model_plots/roc_curves.png', dpi=300, bbox_inches='tight')
plt.close(fig)

# ——— 5. F1-Score Bar Charts ———
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
for i, attr in enumerate(attrs):
    ax = axes.flat[i]
    y_pred_labels = np.argmax(y_pred[i], axis=1)
    f1s = f1_score(
        y_te_int[i], y_pred_labels,
        labels=list(range(num_classes[attr])),
        average=None, zero_division=0
    )
    sns.barplot(
        x=list(label_encoders[attr]), y=f1s,
        palette="tab10", ax=ax
    )
    ax.set_title(f'{attr} F1-Scores', fontsize=12)
    ax.set_ylim(0, 1)
    ax.set_ylabel('F1 Score')
    ax.set_xlabel('')
    for idx, val in enumerate(f1s):
        ax.text(idx, val + 0.02, f'{val:.2f}', ha='center', fontsize=9)
plt.tight_layout()
fig.savefig('model_plots/f1_score_barcharts.png', dpi=300, bbox_inches='tight')
plt.close(fig)

# ——— 6. t-SNE of Penultimate Features ———
penult = best_model.layers[-2].output
feat_extractor = Model(best_model.input, penult)
emb = feat_extractor.predict(X_te)
tsne = TSNE(n_components=2, random_state=42)
proj = tsne.fit_transform(emb)

fig, ax = plt.subplots(figsize=(6, 6))
for lbl in np.unique(y_te_int[0]):
    mask = (y_te_int[0] == lbl)
    ax.scatter(
        proj[mask, 0], proj[mask, 1],
        alpha=0.6, label=label_encoders[attrs[0]][lbl]
    )
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_title('t-SNE Projection of Penultimate Features', fontsize=14)
ax.set_xlabel('Dim 1')
ax.set_ylabel('Dim 2')
plt.tight_layout()
fig.savefig('model_plots/tsne_penultimate_features.png', dpi=300, bbox_inches='tight')
plt.close(fig)

print("All plots have been saved in the 'model_plots' directory.")
plt.tight_layout()
plt.show()
# Out:
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:980: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:84: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Users\patel\OneDrive\Desktop\FPR\tf-gpu-venv\Lib\site-packages\sklearn\metrics\_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:105: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:119: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:119: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:119: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:119: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:119: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\394307010.py:119: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 25s 156ms/step
# All plots have been saved in the 'model_plots' directory.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Ensure output folder exists
os.makedirs('model_plots', exist_ok=True)

# ——— 1. Accuracy Bar Chart for All Batch Sizes ———
mean_acc_per_bs = {}
for bs in batch_sizes:
    h = histories[bs].history
    final_accs = [h[f'val_{a}_accuracy'][-1] for a in attrs]
    mean_acc_per_bs[bs] = np.mean(final_accs)

fig, ax = plt.subplots(figsize=(6, 4))
sns.barplot(
    x=list(mean_acc_per_bs.keys()),
    y=list(mean_acc_per_bs.values()),
    palette="tab10",
    ax=ax
)
ax.set_title("Mean Final Validation Accuracy by Batch Size", fontsize=14)
ax.set_xlabel("Batch Size", fontsize=12)
ax.set_ylabel("Mean Validation Accuracy", fontsize=12)
ax.set_ylim(0, 1)
for i, v in enumerate(mean_acc_per_bs.values()):
    ax.text(i, v + 0.02, f"{v:.2f}", ha='center', fontsize=10)
plt.tight_layout()

# Save accuracy bar chart
acc_bar_path = 'model_plots/mean_validation_accuracy_by_batch_size.png'
fig.savefig(acc_bar_path, dpi=300, bbox_inches='tight')
plt.close(fig)
print(f"Saved accuracy bar chart to {acc_bar_path}")

# ——— 2. Overall Confusion Matrix for All Attributes ———
# Build global labels and offsets
offsets = {}
cum = 0
global_labels = []
for a in attrs:
    offsets[a] = cum
    for cls in label_encoders[a]:
        global_labels.append(f"{a}_{cls}")
    cum += num_classes[a]
total_classes = cum

# Flatten true & pred across all attrs
y_true_global = []
y_pred_global = []
for i, a in enumerate(attrs):
    off = offsets[a]
    y_true_global.extend((np.array(y_te_int[i]) + off).tolist())
    y_pred_global.extend((np.argmax(y_pred[i], axis=1) + off).tolist())

cm_overall = confusion_matrix(
    y_true_global,
    y_pred_global,
    labels=np.arange(total_classes)
)

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(
    cm_overall,
    cmap="Blues",
    xticklabels=global_labels,
    yticklabels=global_labels,
    annot=False,
    cbar_kws={'shrink': 0.5},
    ax=ax
)
ax.set_title("Overall Confusion Matrix (All Attributes)", fontsize=14)
ax.set_xlabel("Predicted Label", fontsize=12)
ax.set_ylabel("True Label", fontsize=12)
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()

# Save overall confusion matrix
cm_path = 'model_plots/overall_confusion_matrix_all_attributes.png'
fig.savefig(cm_path, dpi=300, bbox_inches='tight')
plt.close(fig)
print(f"Saved overall confusion matrix to {cm_path}")

plt.tight_layout()
plt.show()
# Out:
# Saved accuracy bar chart to model_plots/mean_validation_accuracy_by_batch_size.png
# C:\Users\patel\AppData\Local\Temp\ipykernel_23512\2238784168.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Saved overall confusion matrix to model_plots/overall_confusion_matrix_all_attributes.png
